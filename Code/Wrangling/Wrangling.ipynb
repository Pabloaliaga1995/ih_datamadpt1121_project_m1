# %%
import pandas as pd

# %%
import numpy as np

# %%
import requests

# %%
import bs4

# %%
from shapely.geometry import Point

# %%
import geopandas as gpd

# %%
import os

# %%
bicimad = pd.read_json("../../Data/biciMad stations.json")

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ...

# %%
long = [float(i.split(",")[0].replace("[", "")) for i in bicimad["geometry_coordinates"]]
long
# Out:
# [-3.7018341,
#  -3.701602938060457,
#  -3.7058415,
#  -3.7069171,
#  -3.7025875,
#  -3.70205,
#  -3.698447,
#  -3.6977715,
#  -3.6954403,
#  -3.7095084,
#  -3.69214,
#  -3.7035918,
#  -3.7061931,
#  -3.7104417,
#  -3.713479,
#  -3.7074453,
#  -3.7075065,
#  -3.7038312,
#  -3.6996502,
#  -3.6954983,
#  -3.6954615,
#  -3.7065376,
#  -3.7081246,
#  -3.710692,
#  -3.7057791,
#  -3.7063837,
#  -3.694475,
#  -3.6956178,
#  -3.6984368,
#  -3.6957355,
#  -3.711504,
#  -3.7068969,
#  -3.7061032,
#  -3.7030833,
#  -3.7036825,
#  -3.7103285,
#  -3.71183,
#  -3.714113,
#  -3.7114762,
#  -3.7088337,
#  -3.7049407,
#  -3.6991147,
#  -3.6982318,
#  -3.7025024,
#  -3.7040666,
#  -3.7110513,
#  -3.7071259,
#  -3.7028265,
#  -3.7022591,
#  -3.6992759,
#  -3.6933463,
#  -3.6935205,
#  -3.7007164,
#  -3.7007111,
#  -3.700423,
#  -3.7020842,
#  -3.7032414,
#  -3.7126299,
#  -3.697895,
#  -3.7043418,
#  -3.688398,
#  -3.6752045,
#  -3.6724968,
#  -3.6708959,
#  -3.6894193,
#  -3.693225,
#  -3.6912023,
# ...

# %%
lat = [float(i.split(",")[1].replace("]", "")) for i in bicimad["geometry_coordinates"]]
lat
# Out:
# [40.4172137,
#  40.41731271011562,
#  40.4205886,
#  40.4302937,
#  40.4285524,
#  40.42852,
#  40.424148,
#  40.4251906,
#  40.4278682,
#  40.4156057,
#  40.42533,
#  40.4269483,
#  40.4284246,
#  40.4273264,
#  40.4260957,
#  40.4262383,
#  40.4230721,
#  40.4232649,
#  40.4207773,
#  40.4218616,
#  40.4192342,
#  40.4200783,
#  40.4202834,
#  40.417908,
#  40.4173703,
#  40.4172781,
#  40.423855,
#  40.4132798,
#  40.4181518,
#  40.4162619,
#  40.4192095,
#  40.4163638,
#  40.4150099,
#  40.4165039,
#  40.4146755,
#  40.4141931,
#  40.4168,
#  40.4108,
#  40.4114041,
#  40.4112744,
#  40.4138846,
#  40.4122047,
#  40.4107085,
#  40.4101564,
#  40.4097617,
#  40.4070358,
#  40.4053153,
#  40.4047851,
#  40.4056107,
#  40.4060941,
#  40.4083684,
#  40.4075606,
#  40.4144226,
#  40.4083061,
#  40.4266828,
#  40.4239757,
#  40.4184192,
#  40.4295658,
#  40.4222862,
#  40.4255495,
#  40.419752,
#  40.4213983,
#  40.4213148,
#  40.4179237,
#  40.4166834,
#  40.4108472,
#  40.4128372,
# ...

# %%
bicimad["LATITUD"] = lat

# %%
bicimad["LONGITUD"] = long

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ...

# %%
bicimad = bicimad.rename(index=str, columns={"LATITUD": "lat_finish", "LONGITUD": "long_finish"})

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ...

# %%
bicimad1 = pd.DataFrame(bicimad[["name","address","lat_finish","long_finish"]])
bicimad1
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  lat_finish  \
# 0                                  Puerta del Sol nº 1   40.417214
# 1                                  Puerta del Sol nº 1   40.417313
# 2                               Calle Miguel Moya nº 1   40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3   40.430294
# 4                          Calle Manuela Malasaña nº 5   40.428552
# ..                                                 ...         ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...   40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...   40.443420
# ...

# %%
bicimad1["DISTANCIA"] = bicimad1.apply(lambda x: to_mercator(x["lat_finish"],x["long_finish"]), axis = 1)

# %%
bicimad1
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  lat_finish  \
# 0                                  Puerta del Sol nº 1   40.417214
# 1                                  Puerta del Sol nº 1   40.417313
# 2                               Calle Miguel Moya nº 1   40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3   40.430294
# 4                          Calle Manuela Malasaña nº 5   40.428552
# ..                                                 ...         ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...   40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...   40.443420
# ...

# %%
bicimad2 = bicimad1.to_csv("../../Data/bicimad.csv")

# %%
centros = pd.read_csv("../../Data/212769-0-atencion-medica.csv", delimiter=";")

# %%
centros
# Out:
#           PK                                             NOMBRE  \
# 0     134929  Centro Concertado de Atención a las Adicciones...
# 1      53123  Centro Concertado de Atención a las Adicciones...
# 2      11867  Centro de Atención a las Adicciones (CAD) de A...
# 3      11887  Centro de Atención a las Adicciones (CAD) de H...
# 4      11862  Centro de Atención a las Adicciones (CAD) de L...
# ..       ...                                                ...
# 266  7318822  Unidad de Salud Mental de niños y adolescentes...
# 267  7318897  Unidad de Salud Mental de niños y adolescentes...
# 268  4795428                               Unidad móvil Madroño
# 269     8889                Unidad Técnica de Apoyo Diagnóstico
# 270     9154                         Vithas Madrid Arturo Soria
#
#                                    DESCRIPCION-ENTIDAD  \
# 0    El CCAD Cáritas que forma parte de la red del ...
# 1    El CCAD  Casa de Campo que forma parte de la r...
# ...

# %%
centros["TIPO DE LUGAR"] = "Sedes.Centros de atención médica"

# %%
centros = centros.rename(index=str, columns={"LATITUD": "lat_start", "LONGITUD": "long_start"})

# %%
centros
# Out:
#           PK                                             NOMBRE  \
# 0     134929  Centro Concertado de Atención a las Adicciones...
# 1      53123  Centro Concertado de Atención a las Adicciones...
# 2      11867  Centro de Atención a las Adicciones (CAD) de A...
# 3      11887  Centro de Atención a las Adicciones (CAD) de H...
# 4      11862  Centro de Atención a las Adicciones (CAD) de L...
# ..       ...                                                ...
# 266  7318822  Unidad de Salud Mental de niños y adolescentes...
# 267  7318897  Unidad de Salud Mental de niños y adolescentes...
# 268  4795428                               Unidad móvil Madroño
# 269     8889                Unidad Técnica de Apoyo Diagnóstico
# 270     9154                         Vithas Madrid Arturo Soria
#
#                                    DESCRIPCION-ENTIDAD  \
# 0    El CCAD Cáritas que forma parte de la red del ...
# 1    El CCAD  Casa de Campo que forma parte de la r...
# ...

# %%
centros1=pd.DataFrame(centros[["NOMBRE", "TIPO DE LUGAR", "NOMBRE-VIA", "NUM", "lat_start", "long_start"]])
centros1
# Out:
#                                                 NOMBRE  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                         TIPO DE LUGAR       NOMBRE-VIA    NUM  lat_start  \
# 0    Sedes.Centros de atención médica  SANTA HORTENSIA    1.0  40.446053
# 1    Sedes.Centros de atención médica         PORTUGAL    0.0  40.416331
# 2    Sedes.Centros de atención médica          CHOPERA   12.0  40.393057
# ...

# %%
centros2 = centros1.to_json("../../Data/centros.json")

# %%
centros1["DISTANCIA"] = centros1.apply(lambda x: to_mercator(x["lat_start"],x["long_start"]), axis = 1)

# %%
centros1
# Out:
#                                                 NOMBRE  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                         TIPO DE LUGAR       NOMBRE-VIA    NUM  lat_start  \
# 0    Sedes.Centros de atención médica  SANTA HORTENSIA    1.0  40.446053
# 1    Sedes.Centros de atención médica         PORTUGAL    0.0  40.416331
# 2    Sedes.Centros de atención médica          CHOPERA   12.0  40.393057
# ...

# %%
df_bicis = pd.merge(bicimad1, centros1, how ='cross')

# %%
df_bicis
# Out:
#                    name              address  lat_finish  long_finish  \
# 0      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# ...                 ...                  ...         ...          ...
# 71539           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71540           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71541           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71542           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71543           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
#
#                                         DISTANCIA_x  \
# 0      POINT (4499223.648366921 -412373.2851572837)
# ...

# %%
def distance_meters(DISTANCIA_x, DISTANCIA_y):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    return DISTANCIA_x.distance(DISTANCIA_y)

# %%
df_bicis["DISTANCIA"] = df_bicis.apply(lambda x: distance_meters(x["DISTANCIA_x"],x["DISTANCIA_y"]), axis = 1)

# %%
df_bicis
# Out:
#                    name              address  lat_finish  long_finish  \
# 0      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# ...                 ...                  ...         ...          ...
# 71539           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71540           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71541           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71542           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71543           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
#
#                                         DISTANCIA_x  \
# 0      POINT (4499223.648366921 -412373.2851572837)
# ...

# %%
df_final = pd.DataFrame(df_bicis[["NOMBRE", "TIPO DE LUGAR", "NOMBRE-VIA", "NUM", "DISTANCIA", "name", "address"]])
df_final
# Out:
#                                                   NOMBRE  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           TIPO DE LUGAR       NOMBRE-VIA    NUM    DISTANCIA  \
# 0      Sedes.Centros de atención médica  SANTA HORTENSIA    1.0  4764.333123
# 1      Sedes.Centros de atención médica         PORTUGAL    0.0  2473.684432
# ...

# %%
df_final = df_final.rename(index=str, columns={"NOMBRE": "Place of Interest", "TIPO DE LUGAR": "Type of Place", "NOMBRE-VIA": "Place Address", "name": "BiciMad Station", "address": "Station location"})

# %%
df_final
# Out:
#                                        Place of Interest  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           Type of Place    Place Address    NUM    DISTANCIA  \
# 0      Sedes.Centros de atención médica  SANTA HORTENSIA    1.0  4764.333123
# 1      Sedes.Centros de atención médica         PORTUGAL    0.0  2473.684432
# ...

# %%
def coordinates(i):
    for i in centros1["NOMBRE"]:
        for lat_start in centros1["lat_start"]:
            for long_start in centros1["long_start"]:
                return lat_start,long_start

# %%
coordinates("Unidad móvil Madroño")
# Out:
# (40.446053313442704, -3.670276612451652)

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
to_mercator(40.446053313442704, -3.670276612451652)
# Out:
# 0    POINT (4502434.059 -408853.039)
# dtype: geometry

# %%
def distance_meters(DISTANCIA_x, DISTANCIA_y):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    return DISTANCIA_x.distance(DISTANCIA_y)

# %%
#Distancia desde Puerta del Sol A a Centro de Atención a las Adicciones de Chopera
distance_meters(40.417214, -3.701834, 40.393057, -3.698067)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/45/rlv_cg792ys3fdwrjq5ywxjc0000gn/T/ipykernel_2569/2443219684.py in <module>
#       1 #Distancia desde Puerta del Sol A a Centro de Atención a las Adicciones de Chopera
# ----> 2 distance_meters(40.417214, -3.701834, 40.393057, -3.698067)
#
# TypeError: distance_meters() takes 2 positional arguments but 4 were given

# %%
def bicimad_final(lat_finish,long_finish):
    for name in bicimad1:
        for i in bicimad1["name"]:
            for lat in bicimad1["lat_finish"]:
                for long in bicimad1["long_finish"]:
                    return i

# %%
bicimad_final(40.393057, -3.698067)
# Out:
# 'Puerta del Sol A'

# %%
prueba = df_bicis.head(5)
prueba
# Out:
#                name              address  lat_finish  long_finish  \
# 0  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
#
#                                     DISTANCIA_x  \
# 0  POINT (4499223.648366921 -412373.2851572837)
# 1  POINT (4499223.648366921 -412373.2851572837)
# 2  POINT (4499223.648366921 -412373.2851572837)
# 3  POINT (4499223.648366921 -412373.2851572837)
# 4  POINT (4499223.648366921 -412373.2851572837)
#
#                                               NOMBRE  \
# 0  Centro Concertado de Atención a las Adicciones...
# 1  Centro Concertado de Atención a las Adicciones...
# 2  Centro de Atención a las Adicciones (CAD) de A...
# 3  Centro de Atención a las Adicciones (CAD) de H...
# ...

# %%
prueba["DISTANCIA"] = prueba.apply(lambda x: distance_meters(x["DISTANCIA_x"],x["DISTANCIA_y"]), axis = 1)
# Out:
# /Users/pabloaliagagato/applications/envs/project1/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
prueba
# Out:
#                name              address  lat_finish  long_finish  \
# 0  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4  Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
#
#                                     DISTANCIA_x  \
# 0  POINT (4499223.648366921 -412373.2851572837)
# 1  POINT (4499223.648366921 -412373.2851572837)
# 2  POINT (4499223.648366921 -412373.2851572837)
# 3  POINT (4499223.648366921 -412373.2851572837)
# 4  POINT (4499223.648366921 -412373.2851572837)
#
#                                               NOMBRE  \
# 0  Centro Concertado de Atención a las Adicciones...
# 1  Centro Concertado de Atención a las Adicciones...
# 2  Centro de Atención a las Adicciones (CAD) de A...
# 3  Centro de Atención a las Adicciones (CAD) de H...
# ...
