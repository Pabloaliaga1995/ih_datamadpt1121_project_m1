# %%
import pandas as pd

# %%
import numpy as np

# %%
import requests

# %%
import bs4

# %%
from shapely.geometry import Point

# %%
import geopandas as gpd

# %%
import os

# %%
bicimad = pd.read_json("../../Data/biciMad stations.json")

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261          Calle José Antonio Novais frente al nº 12         1
# 262                          Avenida Complutense nº 23         1
# 263                                Calle Zurbano nº 90         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          15          11                   0
# 1               0           30          22           4                   0
# 2               0           24          12          11                   0
# 3               0           18           4          11                   0
# 4               0           24          12          12                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           0          24                   0
# 260             0           24          12          12                   0
# 261             0           24           9          14                   0
# 262             0           24           5          18                   0
# 263             0           24           6          15                   0
#
#     geometry_type                     geometry_coordinates
# 0           Point                 [-3.7018341, 40.4172137]
# 1           Point  [-3.701602938060457, 40.41731271011562]
# 2           Point                 [-3.7058415, 40.4205886]
# 3           Point                 [-3.7069171, 40.4302937]
# 4           Point                 [-3.7025875, 40.4285524]
# ..            ...                                      ...
# 259         Point                     [-3.72699, 40.44375]
# 260         Point                     [-3.72693, 40.44342]
# 261         Point                 [-3.7272945, 40.4483322]
# 262         Point                     [-3.72937, 40.45109]
# 263         Point                     [-3.69281, 40.43837]
#
# [264 rows x 13 columns]

# %%
long = [float(i.split(",")[0].replace("[", "")) for i in bicimad["geometry_coordinates"]]
long
# Out:
# [-3.7018341,
#  -3.701602938060457,
#  -3.7058415,
#  -3.7069171,
#  -3.7025875,
#  -3.70205,
#  -3.698447,
#  -3.6977715,
#  -3.6954403,
#  -3.7095084,
#  -3.69214,
#  -3.7035918,
#  -3.7061931,
#  -3.7104417,
#  -3.713479,
#  -3.7074453,
#  -3.7075065,
#  -3.7038312,
#  -3.6996502,
#  -3.6954983,
#  -3.6954615,
#  -3.7065376,
#  -3.7081246,
#  -3.710692,
#  -3.7057791,
#  -3.7063837,
#  -3.694475,
#  -3.6956178,
#  -3.6984368,
#  -3.6957355,
#  -3.711504,
#  -3.7068969,
#  -3.7061032,
#  -3.7030833,
#  -3.7036825,
#  -3.7103285,
#  -3.71183,
#  -3.714113,
#  -3.7114762,
#  -3.7088337,
#  -3.7049407,
#  -3.6991147,
#  -3.6982318,
#  -3.7025024,
#  -3.7040666,
#  -3.7110513,
#  -3.7071259,
#  -3.7028265,
#  -3.7022591,
#  -3.6992759,
#  -3.6933463,
#  -3.6935205,
#  -3.7007164,
#  -3.7007111,
#  -3.700423,
#  -3.7020842,
#  -3.7032414,
#  -3.7126299,
#  -3.697895,
#  -3.7043418,
#  -3.688398,
#  -3.6752045,
#  -3.6724968,
#  -3.6708959,
#  -3.6894193,
#  -3.693225,
#  -3.6912023,
#  -3.688822,
#  -3.6779232,
#  -3.6738865,
#  -3.6691838,
#  -3.6689089,
#  -3.6766813,
#  -3.6784838,
#  -3.6751352,
#  -3.670422,
#  -3.6744,
#  -3.6803874,
#  -3.6902255,
#  -3.6901234,
#  -3.691987,
#  -3.6697526,
#  -3.6745323,
#  -3.6726019,
#  -3.680008,
#  -3.6933498,
#  -3.6832566,
#  -3.6838303,
#  -3.6752024,
#  -3.6837876,
#  -3.6787441,
#  -3.6865463,
#  -3.6893698,
#  -3.690756,
#  -3.6870548,
#  -3.6821793,
#  -3.6805189,
#  -3.6758383,
#  -3.6738714,
#  -3.67384,
#  -3.6691524,
#  -3.6840229,
#  -3.68653,
#  -3.68958,
#  -3.68745,
#  -3.6877227,
#  -3.687745,
#  -3.6884369,
#  -3.6706024,
#  -3.6816402,
#  -3.7200845,
#  -3.7175435,
#  -3.7179687,
#  -3.7246532,
#  -3.7205129,
#  -3.7174158,
#  -3.7170448,
#  -3.711603,
#  -3.711703,
#  -3.7188898,
#  -3.6882407,
#  -3.6863218,
#  -3.6944768,
#  -3.6987665,
#  -3.6967169,
#  -3.7133412,
#  -3.7224983,
#  -3.7108108,
#  -3.7064516,
#  -3.6975708,
#  -3.6945025,
#  -3.6894151,
#  -3.684715,
#  -3.7009675,
#  -3.691533,
#  -3.6946218,
#  -3.6990077,
#  -3.693085,
#  -3.6817962,
#  -3.6952943,
#  -3.6881689,
#  -3.6905604,
#  -3.6797296,
#  -3.7036675,
#  -3.7001669,
#  -3.690861,
#  -3.6853312,
#  -3.6956047,
#  -3.6917932,
#  -3.6787169,
#  -3.7040344,
#  -3.70164,
#  -3.6927821,
#  -3.6907784,
#  -3.7154329,
#  -3.6982353,
#  -3.6831578,
#  -3.7015686,
#  -3.6948626,
#  -3.6892368,
#  -3.678492,
#  -3.6879154,
#  -3.708439,
#  -3.6993465,
#  -3.6758555,
#  -3.6712823,
#  -3.6763439,
#  -3.6835926,
#  -3.7135833,
#  -3.717487,
#  -3.6959166,
#  -3.7138055,
#  -3.7043611,
#  -3.6983888,
#  -3.6935833,
#  -3.7023918,
#  -3.7065277,
#  -3.6983055,
#  -3.6937222,
#  -3.6941944,
#  -3.6788343,
#  -3.66925,
#  -3.6758888,
#  -3.6766111,
#  -3.6657777,
#  -3.669339,
#  -3.6653055,
#  -3.6615277,
#  -3.6782777,
#  -3.6638888,
#  -3.6590555,
#  -3.6554918,
#  -3.6835833,
#  -3.674,
#  -3.6714166,
#  -3.6655555,
#  -3.6772222,
#  -3.6754444,
#  -3.6751388,
#  -3.6780555,
#  -3.6915555,
#  -3.7149166,
#  -3.7046666,
#  -3.7038333,
#  -3.7080833,
#  -3.7144722,
#  -3.7041666,
#  -3.7032777,
#  -3.6989925,
#  -3.6973333,
#  -3.6886388,
#  -3.6887722,
#  -3.7026735,
#  -3.70239,
#  -3.716591,
#  -3.70017,
#  -3.65741,
#  -3.640994,
#  -3.728318,
#  -3.688463,
#  -3.65779,
#  -3.646697,
#  -3.65122,
#  -3.634587,
#  -3.7026789,
#  -3.7244893989507686,
#  -3.728533714316331,
#  -3.660188083470652,
#  -3.6607768678037744,
#  -3.7080429728445563,
#  -3.6659362429356372,
#  -3.64835857929032,
#  -3.648958444298144,
#  -3.6557656204708775,
#  -3.6485306152875148,
#  -3.6555552857442697,
#  -3.651034981803642,
#  -3.6903589643353483,
#  -3.7172213778842007,
#  -3.710525,
#  -3.6929376751795306,
#  -3.708002730875242,
#  -3.66096,
#  -3.66779,
#  -3.66301,
#  -3.67012,
#  -3.71757,
#  -3.71019,
#  -3.69928,
#  -3.68797,
#  -3.68532,
#  -3.68609,
#  -3.66683,
#  -3.68391,
#  -3.68844,
#  -3.67712,
#  -3.68514,
#  -3.71383,
#  -3.72997,
#  -3.72699,
#  -3.72693,
#  -3.7272945,
#  -3.72937,
#  -3.69281]

# %%
lat = [float(i.split(",")[1].replace("]", "")) for i in bicimad["geometry_coordinates"]]
lat
# Out:
# [40.4172137,
#  40.41731271011562,
#  40.4205886,
#  40.4302937,
#  40.4285524,
#  40.42852,
#  40.424148,
#  40.4251906,
#  40.4278682,
#  40.4156057,
#  40.42533,
#  40.4269483,
#  40.4284246,
#  40.4273264,
#  40.4260957,
#  40.4262383,
#  40.4230721,
#  40.4232649,
#  40.4207773,
#  40.4218616,
#  40.4192342,
#  40.4200783,
#  40.4202834,
#  40.417908,
#  40.4173703,
#  40.4172781,
#  40.423855,
#  40.4132798,
#  40.4181518,
#  40.4162619,
#  40.4192095,
#  40.4163638,
#  40.4150099,
#  40.4165039,
#  40.4146755,
#  40.4141931,
#  40.4168,
#  40.4108,
#  40.4114041,
#  40.4112744,
#  40.4138846,
#  40.4122047,
#  40.4107085,
#  40.4101564,
#  40.4097617,
#  40.4070358,
#  40.4053153,
#  40.4047851,
#  40.4056107,
#  40.4060941,
#  40.4083684,
#  40.4075606,
#  40.4144226,
#  40.4083061,
#  40.4266828,
#  40.4239757,
#  40.4184192,
#  40.4295658,
#  40.4222862,
#  40.4255495,
#  40.419752,
#  40.4213983,
#  40.4213148,
#  40.4179237,
#  40.4166834,
#  40.4108472,
#  40.4128372,
#  40.409808,
#  40.4153053,
#  40.4159569,
#  40.4157413,
#  40.4114475,
#  40.4117627,
#  40.4082805,
#  40.4071304,
#  40.40635,
#  40.400789,
#  40.4051451,
#  40.4075685,
#  40.4074902,
#  40.409297,
#  40.4084556,
#  40.4132995,
#  40.4032501,
#  40.421501,
#  40.4186516,
#  40.427736,
#  40.4313576,
#  40.4272582,
#  40.4250361,
#  40.426134,
#  40.4262945,
#  40.4257046,
#  40.4232153,
#  40.4226584,
#  40.422064,
#  40.4222969,
#  40.4239447,
#  40.4261851,
#  40.42478,
#  40.4231526,
#  40.4211802,
#  40.43037,
#  40.42677,
#  40.42699,
#  40.4251002,
#  40.424963,
#  40.4215246,
#  40.4273005,
#  40.4300481,
#  40.4347895,
#  40.4337322,
#  40.4341006,
#  40.4325991,
#  40.427657,
#  40.4277456,
#  40.4253944,
#  40.42402,
#  40.42412,
#  40.4309797,
#  40.400781,
#  40.4013216,
#  40.4032208,
#  40.4017926,
#  40.4291992,
#  40.4306458,
#  40.4219665,
#  40.4034076,
#  40.4035988,
#  40.3928821,
#  40.3972616,
#  40.4591366,
#  40.4585318,
#  40.4572824,
#  40.4592351,
#  40.4548456,
#  40.4527164,
#  40.4522454,
#  40.4510188,
#  40.4489101,
#  40.4498613,
#  40.4488924,
#  40.4483269,
#  40.4463667,
#  40.447125,
#  40.4453307,
#  40.445411,
#  40.4440297,
#  40.4457414,
#  40.4442258,
#  40.4418402,
#  40.44156,
#  40.4415974,
#  40.4396792,
#  40.438994,
#  40.4383865,
#  40.4385127,
#  40.4344731,
#  40.435285,
#  40.4355143,
#  40.4345973,
#  40.4334087,
#  40.4338516,
#  40.4309524,
#  40.4323655,
#  40.429887,
#  40.4572466,
#  40.4543852,
#  40.4138333,
#  40.413736,
#  40.4044722,
#  40.4016111,
#  40.401,
#  40.39975,
#  40.4008888,
#  40.3981798,
#  40.3974444,
#  40.3962222,
#  40.39425,
#  40.3914722,
#  40.4029202,
#  40.3979722,
#  40.3941388,
#  40.41825,
#  40.4186666,
#  40.425635,
#  40.426,
#  40.4250833,
#  40.4290555,
#  40.4301666,
#  40.4311944,
#  40.4351256,
#  40.4343333,
#  40.4346388,
#  40.4318611,
#  40.4324722,
#  40.43725,
#  40.4392222,
#  40.4441388,
#  40.4515833,
#  40.4331111,
#  40.4343611,
#  40.4336944,
#  40.4386944,
#  40.4411388,
#  40.44175,
#  40.4476666,
#  40.4535,
#  40.4607502,
#  40.4630277,
#  40.4663611,
#  40.4656779,
#  40.419674,
#  40.42059,
#  40.398247,
#  40.38895,
#  40.44315,
#  40.429706,
#  40.413764,
#  40.481086,
#  40.41053,
#  40.408264,
#  40.40617,
#  40.400368,
#  40.3917871,
#  40.406837862773465,
#  40.40913630273305,
#  40.40248333540473,
#  40.39901531507069,
#  40.39440607959559,
#  40.39382977920336,
#  40.43715089959262,
#  40.44370542379883,
#  40.43965673033275,
#  40.43272086245887,
#  40.422962108947424,
#  40.426207143200884,
#  40.389258643579105,
#  40.40765396169372,
#  40.451333,
#  40.45619382579544,
#  40.45673408797698,
#  40.43666,
#  40.4378,
#  40.43865,
#  40.43503,
#  40.44003,
#  40.4364,
#  40.43604,
#  40.47435,
#  40.47938,
#  40.44106,
#  40.44421,
#  40.4716,
#  40.45546,
#  40.46041,
#  40.46361,
#  40.44635,
#  40.43896,
#  40.44375,
#  40.44342,
#  40.4483322,
#  40.45109,
#  40.43837]

# %%
bicimad["LATITUD"] = lat

# %%
bicimad["LONGITUD"] = long

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261          Calle José Antonio Novais frente al nº 12         1
# 262                          Avenida Complutense nº 23         1
# 263                                Calle Zurbano nº 90         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          15          11                   0
# 1               0           30          22           4                   0
# 2               0           24          12          11                   0
# 3               0           18           4          11                   0
# 4               0           24          12          12                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           0          24                   0
# 260             0           24          12          12                   0
# 261             0           24           9          14                   0
# 262             0           24           5          18                   0
# 263             0           24           6          15                   0
#
#     geometry_type                     geometry_coordinates    LATITUD  \
# 0           Point                 [-3.7018341, 40.4172137]  40.417214
# 1           Point  [-3.701602938060457, 40.41731271011562]  40.417313
# 2           Point                 [-3.7058415, 40.4205886]  40.420589
# 3           Point                 [-3.7069171, 40.4302937]  40.430294
# 4           Point                 [-3.7025875, 40.4285524]  40.428552
# ..            ...                                      ...        ...
# 259         Point                     [-3.72699, 40.44375]  40.443750
# 260         Point                     [-3.72693, 40.44342]  40.443420
# 261         Point                 [-3.7272945, 40.4483322]  40.448332
# 262         Point                     [-3.72937, 40.45109]  40.451090
# 263         Point                     [-3.69281, 40.43837]  40.438370
#
#      LONGITUD
# 0   -3.701834
# 1   -3.701603
# 2   -3.705842
# 3   -3.706917
# 4   -3.702587
# ..        ...
# 259 -3.726990
# 260 -3.726930
# 261 -3.727295
# 262 -3.729370
# 263 -3.692810
#
# [264 rows x 15 columns]

# %%
bicimad = bicimad.rename(index=str, columns={"LATITUD": "lat_finish", "LONGITUD": "long_finish"})

# %%
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261          Calle José Antonio Novais frente al nº 12         1
# 262                          Avenida Complutense nº 23         1
# 263                                Calle Zurbano nº 90         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          15          11                   0
# 1               0           30          22           4                   0
# 2               0           24          12          11                   0
# 3               0           18           4          11                   0
# 4               0           24          12          12                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           0          24                   0
# 260             0           24          12          12                   0
# 261             0           24           9          14                   0
# 262             0           24           5          18                   0
# 263             0           24           6          15                   0
#
#     geometry_type                     geometry_coordinates  lat_finish  \
# 0           Point                 [-3.7018341, 40.4172137]   40.417214
# 1           Point  [-3.701602938060457, 40.41731271011562]   40.417313
# 2           Point                 [-3.7058415, 40.4205886]   40.420589
# 3           Point                 [-3.7069171, 40.4302937]   40.430294
# 4           Point                 [-3.7025875, 40.4285524]   40.428552
# ..            ...                                      ...         ...
# 259         Point                     [-3.72699, 40.44375]   40.443750
# 260         Point                     [-3.72693, 40.44342]   40.443420
# 261         Point                 [-3.7272945, 40.4483322]   40.448332
# 262         Point                     [-3.72937, 40.45109]   40.451090
# 263         Point                     [-3.69281, 40.43837]   40.438370
#
#      long_finish
# 0      -3.701834
# 1      -3.701603
# 2      -3.705842
# 3      -3.706917
# 4      -3.702587
# ..           ...
# 259    -3.726990
# 260    -3.726930
# 261    -3.727295
# 262    -3.729370
# 263    -3.692810
#
# [264 rows x 15 columns]

# %%
bicimad1 = pd.DataFrame(bicimad[["name","address","lat_finish","long_finish"]])
bicimad1
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  lat_finish  \
# 0                                  Puerta del Sol nº 1   40.417214
# 1                                  Puerta del Sol nº 1   40.417313
# 2                               Calle Miguel Moya nº 1   40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3   40.430294
# 4                          Calle Manuela Malasaña nº 5   40.428552
# ..                                                 ...         ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...   40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...   40.443420
# 261          Calle José Antonio Novais frente al nº 12   40.448332
# 262                          Avenida Complutense nº 23   40.451090
# 263                                Calle Zurbano nº 90   40.438370
#
#      long_finish
# 0      -3.701834
# 1      -3.701603
# 2      -3.705842
# 3      -3.706917
# 4      -3.702587
# ..           ...
# 259    -3.726990
# 260    -3.726930
# 261    -3.727295
# 262    -3.729370
# 263    -3.692810
#
# [264 rows x 4 columns]

# %%
bicimad1["DISTANCIA"] = bicimad1.apply(lambda x: to_mercator(x["lat_finish"],x["long_finish"]), axis = 1)

# %%
bicimad1
# Out:
#                        name  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259  Ciudad Universitaria 1
# 260  Ciudad Universitaria 2
# 261       Facultad Biología
# 262        Facultad Derecho
# 263                 Zurbano
#
#                                                address  lat_finish  \
# 0                                  Puerta del Sol nº 1   40.417214
# 1                                  Puerta del Sol nº 1   40.417313
# 2                               Calle Miguel Moya nº 1   40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3   40.430294
# 4                          Calle Manuela Malasaña nº 5   40.428552
# ..                                                 ...         ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...   40.443750
# 260  Avenida de la Complutense (Metro Ciudad Univer...   40.443420
# 261          Calle José Antonio Novais frente al nº 12   40.448332
# 262                          Avenida Complutense nº 23   40.451090
# 263                                Calle Zurbano nº 90   40.438370
#
#      long_finish                                     DISTANCIA
# 0      -3.701834  POINT (4499223.648366921 -412373.2851572837)
# 1      -3.701603   POINT (4499234.670122574 -412347.498528782)
# 2      -3.705842  POINT (4499599.340516399 -412820.3206106317)
# 3      -3.706917  POINT (4500679.707306497 -412940.3068148262)
# 4      -3.702587  POINT (4500485.866677178 -412457.3286497012)
# ..           ...                                           ...
# 259    -3.726990  POINT (4502177.655770458 -415179.5220676512)
# 260    -3.726930  POINT (4502140.920338497 -415172.8287427756)
# 261    -3.727295  POINT (4502687.743941171 -415213.4906984274)
# 262    -3.729370    POINT (4502994.74083288 -415445.024322674)
# 263    -3.692810  POINT (4501578.756909991 -411366.6317244973)
#
# [264 rows x 5 columns]

# %%
bicimad2 = bicimad1.to_csv("../../Data/bicimad.csv")

# %%
centros = requests.get('https://datos.madrid.es/egob/catalogo/212769-0-atencion-medica.json')
centros = centros.json()

# %%
centros
# Out:
# {'@context': {'c': 'http://www.w3.org/2002/12/cal#',
#   'dcterms': 'http://purl.org/dc/terms/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#   'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#   'vcard': 'http://www.w3.org/2006/vcard/ns#',
#   'schema': 'https://schema.org/',
#   'title': 'vcard:fn',
#   'id': 'dcterms:identifier',
#   'relation': 'dcterms:relation',
#   'references': 'dcterms:references',
#   'address': 'vcard:adr',
#   'area': 'loc:barrio',
#   'district': 'loc:distrito',
#   'locality': 'vcard:locality',
#   'postal-code': 'vcard:postal-code',
#   'street-address': 'vcard:street-address',
#   'location': 'vcard:geo',
#   'latitude': 'geo:lat',
#   'longitude': 'geo:long',
#   'organization': 'vcard:org',
#   'organization-desc': 'dcterms:description',
#   'accesibility': 'org:accesibilidad',
#   'services': 'org:servicios',
#   'schedule': 'org:horario',
#   'organization-name': 'vcard:organization-name',
#   'description': 'c:summary',
#   'link': 'c:url',
#   'uid': 'c:uid',
#   'dtstart': 'c:dtstart',
#   'dtend': 'c:dtend',
#   'time': 'c:time',
#   'excluded-days': 'c:exdate',
#   'event-location': 'c:location',
#   'free': 'schema:free',
#   'price': 'c:resource',
#   'recurrence': 'c:rrule',
#   'days': 'c:byday',
#   'frequency': 'c:freq',
#   'interval': 'c:interval',
#   'audience': 'dc:audience'},
#  '@graph': [{'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/134929-centro-concertado-atencion-adicciones-ccad-caritas-madrid.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '134929',
#    'title': 'Centro Concertado de Atención a las Adicciones (CCAD) Cáritas Madrid',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=13ba654d9d91f010VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamartin'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamartin/Barrio/Prosperidad'},
#     'locality': 'MADRID',
#     'postal-code': '28002',
#     'street-address': 'CALLE SANTA HORTENSIA 1'},
#    'location': {'latitude': 40.446053313442704,
#     'longitude': -3.6702766124516515},
#    'organization': {'organization-desc': 'El CCAD Cáritas que forma parte de la red del Instituto de Adicciones de la Ciudad de Madrid, presta una atención personalizada individual y/o grupal en régimen ambulatorio a las personas que presentan problemas de abuso o dependencia del alcohol y de otras drogas.\xa0\xa0Bus: 9, 73, N2Metro: Alfonso XIII (L4), Prosperidad (L4) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'De lunes a viernes mañanas de 9 a 14 horas, tardes de 15:30 a 18 horas',
#     'services': 'Valoración interdisciplinar del/de la paciente. Tratamiento integral que además de abordar el propio consumo, contempla aspectos sanitarios, psicológicos, sociales y ocupacionales. Intervenciones de reducción del daño y riesgos dirigidas a disminuir los efectos del consumo de drogas y conseguir mejoras en la salud cuando no se consigue la abstinencia. Tratamientos farmacológicos, incluyen la utilización de tratamientos con sustitutivos opiáceos como metadona. Apoyo a la integración social y laboral del paciente. Intervención con las familias, tanto con las que acompañan a la persona directamente afectada, como con aquellas otras que solicitan ayuda sin que el consumidor haya decidido ponerse en tratamiento. Derivación a recursos externos de apoyo al tratamiento y a la reinserción social, que complementan y apoyan el trabajo realizado desde los CAD.',
#     'organization-name': 'Centro Concertado de Atención a las Adicciones (CCAD) Cáritas Madrid'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/53123-centro-concertado-atencion-adicciones-ccad-casa-campo-cruz-roja-.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '53123',
#    'title': 'Centro Concertado de Atención a las Adicciones (CCAD) Casa de Campo (Cruz Roja)',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=97d3598d1351c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina/Barrio/PuertaAngel'},
#     'locality': 'MADRID',
#     'postal-code': '28011',
#     'street-address': 'AVENIDA PORTUGAL'},
#    'location': {'latitude': 40.41633059885888,
#     'longitude': -3.7239914257003304},
#    'organization': {'organization-desc': 'El CCAD  Casa de Campo que forma parte de la red del Instituto de Adicciones de la Ciudad de Madrid, presta una atención personalizada individual y/o grupal en régimen ambulatorio a las personas que presentan problemas de abuso o dependencia del alcohol y de otras drogas.\xa0Forma de acceso: directo\xa0Bus: 31, 33, 36, 39, 65, 138 Metro:Puerta del Angel (L6), Lago (L10) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'De lunes a viernes de 9 a 17 horas',
#     'services': 'Valoración interdisciplinar del paciente. Tratamiento integral que además de abordar el propio consumo, contempla aspectos sanitarios, psicológicos, sociales y ocupacionales. Intervenciones de reducción del daño y riesgos dirigidas a disminuir los efectos del consumo de drogas y conseguir mejoras en la salud cuando no se consigue la abstinencia. Tratamientos farmacológicos, incluyen la utilización de tratamientos con sustitutivos opiáceos como metadona. Apoyo a la integración social y laboral del/de la paciente. Intervención con las familias, tanto con las que acompañan a la persona directamente afectada, como con aquellas otras que solicitan ayuda sin que el consumidor haya decidido ponerse en tratamiento. Derivación a recursos externos de apoyo al tratamiento y a la reinserción social, que complementan y apoyan el trabajo realizado desde los CAD.',
#     'organization-name': 'Centro Concertado de Atención a las Adicciones (CCAD) Casa de Campo (Cruz Roja)'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11867-centro-atencion-adicciones-cad-arganzuela.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11867',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Arganzuela',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=de74d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Arganzuela'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Arganzuela/Barrio/Chopera'},
#     'locality': 'MADRID',
#     'postal-code': '28045',
#     'street-address': 'PASEO CHOPERA 12'},
#    'location': {'latitude': 40.39305745803064,
#     'longitude': -3.6980673403694104},
#    'organization': {'organization-desc': '\xa0Forma de acceso: directo, a través de los servicios municipales, servicios de salud o entidades comunitarias.  Ámbito de actuación:  Distrito de Arganzuela Distrito de Centro Distrito de Retiro Distrito de Salamanca\xa0Bus: 6 , 8 , 18 , 19 , 22 , 45 , 47 , 76 , 78 , 79 , 85 , 86 , 88 , 123 , 148 , 247Metro: Legazpi (L 3 y L 6) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas  Viernes de 8 a 15:00 horas    Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas  Viernes de 8 a 14:00 horas     Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Arganzuela'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11887-centro-atencion-adicciones-cad-hortaleza.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11887',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Hortaleza',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=25a4d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Hortaleza'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Hortaleza/Barrio/Canillas'},
#     'locality': 'MADRID',
#     'postal-code': '28043',
#     'street-address': 'CALLE MINAYA 7'},
#    'location': {'latitude': 40.468288815918534,
#     'longitude': -3.636150078507109},
#    'organization': {'organization-desc': '\xa0Acceso: directo, a través de los servicios municipales, servicios de salud o entidades comunitarias  Ámbito de actuación:  Distrito de Hortaleza Distrito de Chamartín Distrito de Barajas Distrito Ciudad Lineal los barrios: San Juan Bautista, Colina, Atalaya y Costillares\xa0Bus: 73, 87, 104, 112, 120, 125, 153, 172Metro: Mar de Cristal (L4, L8) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Hortaleza'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11862-centro-atencion-adicciones-cad-latina.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11862',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Latina',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=7bc4d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina/Barrio/Aluche'},
#     'locality': 'MADRID',
#     'postal-code': '28047',
#     'street-address': 'CALLE CAMARENA 10'},
#    'location': {'latitude': 40.39597072367931,
#     'longitude': -3.7562716852987847},
#    'organization': {'organization-desc': '\xa0Acceso: directo, a traves de los servicios municipales, servicios de salud o entidades comunitarias  Ámbito de actuación:  Distrito de Latina Distrito de Moncloa - Aravaca: barrios de Arg&amp;uuml;elles, Plantío, Aravaca y Casa de Campo Distrito Carabanchel: barrios de San Isidro, Vista Alegre y Puerta Bonita.\xa0Bus: 25 , 31, 138Metro: Laguna (L 6), Casa de Campo (L 10)',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Latina'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11865-centro-atencion-adicciones-cad-san-blas.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11865',
#    'title': 'Centro de Atención a las Adicciones (CAD) de San Blas',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=c1f4d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Distrito'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Distrito/Barrio/ElSalvador'},
#     'locality': 'MADRID',
#     'postal-code': '28027',
#     'street-address': 'CALLE ALCALA 527'},
#    'location': {'latitude': 40.44097774609991,
#     'longitude': -3.6271316821262958},
#    'organization': {'organization-desc': '\xa0Acceso: directo, a traves de los servicios municipales, servicios de salud o entidades comunitarias  Ámbito de actuación  Distrito de San Blas Distrito de Ciudad Lineal los barrios: Ventas, Pueblo Nuevo, Quintana, Concepción y San Pascual Distrito de Vicálvaro\xa0Bus: 77, 104, 105, 775Metro: Suances (L 5)',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de San Blas'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11866-centro-atencion-adicciones-cad-tetuan.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11866',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Tetuán',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=1815d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan/Barrio/Almenara'},
#     'locality': 'MADRID',
#     'postal-code': '28029',
#     'street-address': 'CALLE PINOS ALTA 122'},
#    'location': {'latitude': 40.47084721439769,
#     'longitude': -3.701561801865397},
#    'organization': {'organization-desc': '\xa0Acceso: directo, a través de los servicios municipales, servicios de salud o entidades comunitarias  Ámbito de actuación  Distrito de Tetuán Distrito de Fuencarral-El Pardo Distrito de Chamberí Distrito de Moncloa-Aravaca: Ciudad Universitaria, Valdezarza y Valdemarín\xa0Bus: 42Metro: Ventilla (L-9), Valdeacederas (L-1) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Tetuán'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11864-centro-atencion-adicciones-cad-vallecas.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11864',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Vallecas',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=6e35d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas/Barrio/SanDiego'},
#     'locality': 'MADRID',
#     'postal-code': '28053',
#     'street-address': 'CALLE CONCORDIA 17'},
#    'location': {'latitude': 40.39501488341387,
#     'longitude': -3.665565995938502},
#    'organization': {'organization-desc': '\xa0Acceso: directo, a traves de los servicios municipales, servicios de salud o entidades comunitarias  Ámbito de actuación  Distrito de Villa de Vallecas Distrito de Puente de Vallecas Distrito de Moratalaz\xa0Bus: 10, 24, 54, 57, 58, 111, 136, 140, 310Metro: Nueva Numancia (L1) Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Vallecas'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11863-centro-atencion-adicciones-cad-villaverde.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11863',
#    'title': 'Centro de Atención a las Adicciones (CAD) de Villaverde',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=b465d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Villaverde'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Villaverde/Barrio/SanAndres'},
#     'locality': 'MADRID',
#     'postal-code': '28021',
#     'street-address': 'CALLE VERDE VIENTO 16'},
#    'location': {'latitude': 40.35231468998616,
#     'longitude': -3.717783527602668},
#    'organization': {'organization-desc': '\xa0Acceso: Directo a través de los servicios municipales, servicios de salud o entidades comunitarias.  Ámbito de Actuación  Distrito de Villaverde. Distrito de Usera. Distrito de Carabanchel, los barrios: Comillas, Opañel, Abrantes y Buenavista\xa0Bus: 76Renfe: Cercanías Puente Alcocer Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Horario ordinario:  De lunes a jueves de 8:30 a 20 horas Viernes de 8 a 15:00 horas   Horario verano:  Del 15 al 30 de junio y del 1 al 15 de septiembre  De lunes a jueves de 8 a 19:30 horas Viernes de 8 a 14:00 horas   Del 1 de julio al 31 de agosto  De lunes a viernes de 8 a 14:00 horas',
#     'services': 'Valoración por equipo interdisciplinar Tratamiento ambulatorio y reinserción de drododependientes, a través de diferentes programas Atención a familiares Derivación a otros recursos: comunidades terapéuticas, pisos de reinserción, talleres Atención y tratamiento individualizado, según los casos.',
#     'organization-name': 'Centro de Atención a las Adicciones (CAD) de Villaverde'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11868-centro-atencion-integral-drogodependientes-caid-este.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11868',
#    'title': 'Centro de Atención Integral a Drogodependientes CAID Este',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=2385d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/SanBlas-Canillejas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/SanBlas-Canillejas/Barrio/Hellin'},
#     'locality': 'MADRID',
#     'postal-code': '28037',
#     'street-address': 'PLAZA CIVICA  esquina C/ Pobladura del Valle'},
#    'location': {'latitude': 40.433034436825466,
#     'longitude': -3.6165885100628414},
#    'organization': {'organization-desc': 'Centro de la red asistencial para las adicciones de la Comunidad de Madrid\xa0\xa0Metro: San Blas (línea 7)  Bus: 4, 38 , 48, 153',
#     'accesibility': '3',
#     'schedule': 'Lunes a viernes, de 9 a 20 horas.',
#     'services': 'Servicio de información y orientación. Servicio de valoración, diagnóstico y plan terapéutico. Servicio de seguimiente y control terapéutico. Servicio de atención familiar.',
#     'organization-name': 'Centro de Atención Integral a Drogodependientes CAID Este'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11882-centro-atencion-integral-drogodependientes-caid-norte.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11882',
#    'title': 'Centro de Atención Integral a Drogodependientes CAID Norte',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=91a5d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan/Barrio/Berruguete'},
#     'locality': 'MADRID',
#     'postal-code': '28039',
#     'street-address': 'CALLE NUESTRA SEÑORA DEL CARMEN 46'},
#    'location': {'latitude': 40.46123735083859,
#     'longitude': -3.7040802461239917},
#    'organization': {'organization-desc': 'Centro de la red asistencial para las adicciones de la Comunidad de Madrid.\xa0\xa0Metro: Tetuán (línea 1)  Bus: 11, 66, 124',
#     'accesibility': '3',
#     'schedule': 'De lunes a viernes, de 9 a 21 horas.',
#     'services': 'Servicio de información y orientación. Servicio de valoración, diagnóstico y plan terapéutico. Servicio de seguimiente y control terapéutico. Servicio de atención familiar.',
#     'organization-name': 'Centro de Atención Integral a Drogodependientes CAID Norte'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11884-centro-atencion-integral-drogodependientes-caid-sur-usera.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11884',
#    'title': 'Centro de Atención Integral a Drogodependientes CAID Sur-Usera',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=00c5d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Usera'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Usera/Barrio/Pradolongo'},
#     'locality': 'MADRID',
#     'postal-code': '28026',
#     'street-address': 'CALLE JASPE 40'},
#    'location': {'latitude': 40.38089582968084,
#     'longitude': -3.7068597834339667},
#    'organization': {'organization-desc': 'Centro de la red asistencial para las adicciones de la Comunidad de Madrid.\xa0\xa0Metro: Usera (línea 6)  Bus: 6, 78  Renfe: Doce de Octubre (C5)',
#     'accesibility': '3',
#     'schedule': 'Lunes a viernes, de 9 a 21 horas.',
#     'services': 'Servicio de información y orientación. Servicio de valoración, diagnóstico y plan terapéutico. Servicio de seguimiente y control terapéutico. Servicio de atención familiar.',
#     'organization-name': 'Centro de Atención Integral a Drogodependientes CAID Sur-Usera'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/5408374-centro-atencion-integral-drogodependientes-caid-vallecas.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '5408374',
#    'title': 'Centro de Atención Integral a Drogodependientes CAID Vallecas',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=eaa91657da473210VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/VillaDeVallecas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/VillaDeVallecas/Barrio/CascoHVallecas'},
#     'locality': 'MADRID',
#     'postal-code': '28051',
#     'street-address': 'CALLE CINCOVILLAS 5'},
#    'location': {'latitude': 40.3683826319493,
#     'longitude': -3.6237845559205977},
#    'organization': {'organization-desc': 'Centro de la red asistencial para las adicciones de la Comunidad de Madrid.\xa0\xa0Metro: Congosto (línea 1)  Bus: 103, 142',
#     'accesibility': '3',
#     'schedule': 'Lunes a viernes, de 9 a 21 horas.',
#     'services': 'Servicio de información y orientación. Servicio de valoración, diagnóstico y plan terapéutico. Servicio de seguimiente y control terapéutico. Servicio de atención familiar.',
#     'organization-name': 'Centro de Atención Integral a Drogodependientes CAID Vallecas'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11899-centro-atencion-integral-sociosanitaria-nocturno.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '11899',
#    'title': 'Centro de Atención integral sociosanitaria nocturno',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=a946d4985261c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro/Barrio/Justicia'},
#     'locality': 'MADRID',
#     'postal-code': '28004',
#     'street-address': 'CALLE HERMANOS ALVAREZ QUINTERO 3'},
#    'location': {'latitude': 40.42747404776084,
#     'longitude': -3.697485377509971},
#    'organization': {'organization-desc': '\xa0Información Complementaria:   Drogodependientes en fase activa, ó en Programa de Metadona Personas sin hogar Pueden pernoctar\xa0Metro: Alonso Martínez  Bus: 21',
#     'accesibility': '0',
#     'schedule': 'De lunes a domingo de 21 a 8 horas',
#     'services': 'Intercambio de jeringuillas Reparto de preservativos Alimentación básica Asistencia social Programas educativos Asistencia sanitaria básica, higiene, programa de vacunaciones Cena',
#     'organization-name': 'Centro de Atención integral sociosanitaria nocturno'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/5855213-centro-atencion-integral-sociosanitario-diurno-cruz-roja-.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '5855213',
#    'title': 'Centro de Atención integral sociosanitario diurno (Cruz Roja)',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=c5dc3e042111c210VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Centro/Barrio/Justicia'},
#     'locality': 'MADRID',
#     'postal-code': '28004',
#     'street-address': 'CALLE HERMANOS ALVAREZ QUINTERO 3'},
#    'location': {'latitude': 40.42747404776084,
#     'longitude': -3.697485377509971},
#    'organization': {'organization-desc': 'El Centro de atención integral sociosanitario diurno forma parte de la red del Instituto de Adicciones de la Ciudad de Madrid, presta una atención personalizada individual y/o grupal en régimen ambulatorio a las personas que presentan problemas de abuso o dependencia del alcohol y de otras drogas.\xa0Forma de acceso: directo\xa0Metro: Alonso Martínez, L4, L5, L10',
#     'accesibility': '1',
#     'schedule': 'De lunes a viernes de 9 a 17 horas',
#     'services': 'Valoración interdisciplinar del/de la paciente. Tratamiento integral que además de abordar el propio consumo, contempla aspectos sanitarios, psicológicos, sociales y ocupacionales. Intervenciones de reducción del daño y riesgos dirigidas a disminuir los efectos del consumo de drogas y conseguir mejoras en la salud cuando no se consigue la abstinencia. Tratamientos farmacológicos, incluyen la utilización de tratamientos con sustitutivos opiáceos como metadona. Apoyo a la integración social y laboral del/de la paciente. Intervención con las familias, tanto con las que acompañan a la persona directamente afectada, como con aquellas otras que solicitan ayuda sin que el consumidor haya decidido ponerse en tratamiento. Derivación a recursos externos de apoyo al tratamiento y a la reinserción social, que complementan y apoyan el trabajo realizado desde los CAD.',
#     'organization-name': 'Centro de Atención integral sociosanitario diurno (Cruz Roja)'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9176-centro-donacion-sangre-cruz-roja.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/OtrosCentrosMedicos',
#    'id': '9176',
#    'title': 'Centro de donación de sangre de Cruz Roja',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=a61f7a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca/Barrio/CiudadUniversitaria'},
#     'locality': 'MADRID',
#     'postal-code': '28040',
#     'street-address': 'CALLE JUAN MONTALVO 3'},
#    'location': {'latitude': 40.447634266728954,
#     'longitude': -3.709893403930222},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Guzman El Bueno (líneas 6 y 7).  Bus: 127, 44, 45, C2, F, C1.',
#     'accesibility': '1',
#     'schedule': 'De lunes a viernes, de 9:30 a 20:30 horas.',
#     'services': '',
#     'organization-name': 'Centro de donación de sangre de Cruz Roja'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9091-centro-especialidades-periferico-arguelles.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9091',
#    'title': 'Centro de Especialidades Periférico Argüelles',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=4e657a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca/Barrio/Arguelles'},
#     'locality': 'MADRID',
#     'postal-code': '28008',
#     'street-address': 'CALLE QUINTANA 11'},
#    'location': {'latitude': 40.427813991541385,
#     'longitude': -3.717265212211469},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Arg&amp;uuml;elles (líneas 3, 4 y 6), Ventura Rodríguez (línea 3).  Bus: 62, 74.  Bicimad: Estación 114 (calle Quintana 11).  Aparcamiento: Marqués de Urquijo (63) calle Marqués de Urquijo entre calle Princiesa y calle Juan Álvarez Mendizábal.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Argüelles'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9093-centro-especialidades-periferico-avenida-portugal.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9093',
#    'title': 'Centro de Especialidades Periférico Avenida de Portugal',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=d0857a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina/Barrio/PuertaAngel'},
#     'locality': 'MADRID',
#     'postal-code': '28011',
#     'street-address': 'AVENIDA PORTUGAL 155'},
#    'location': {'latitude': 40.41118910558646,
#     'longitude': -3.7378201989857724},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Alto de Extremadura (línea 6).  Bus: 31, 33, 36, 39, 65.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Avenida de Portugal'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9095-centro-especialidades-periferico-carabanchel-alto.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9095',
#    'title': 'Centro de Especialidades Periférico Carabanchel Alto',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=63957a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Carabanchel'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Carabanchel/Barrio/Buenavista'},
#     'locality': 'MADRID',
#     'postal-code': '28044',
#     'street-address': 'CALLE AGUACATE 13'},
#    'location': {'latitude': 40.37199728022393,
#     'longitude': -3.7480055783841606},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Carabanchel Alto (línea 11).  Bus: 108, 118, 121, 131, 47.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Carabanchel Alto'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/6869784-centro-especialidades-periferico-emigrantes.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '6869784',
#    'title': 'Centro de Especialidades Periférico Emigrantes',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=219b06517038d310VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Hortaleza'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Hortaleza/Barrio/Canillas'},
#     'locality': 'MADRID',
#     'postal-code': '28043',
#     'street-address': 'CALLE AREQUIPA 30 PLANTA 3'},
#    'location': {'latitude': 40.46868395687676,
#     'longitude': -3.636377932102786},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Mar de Cristal (líneas 4 y 8).  Bus: 104, 171, T11, 153, 112, 125, 120, 172, 87.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Emigrantes'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/136605-centro-especialidades-periferico-federica-montseny.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '136605',
#    'title': 'Centro de Especialidades Periférico Federica Montseny',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=f3c215a11a81c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas/Barrio/PalomerasSureste'},
#     'locality': 'MADRID',
#     'postal-code': '28038',
#     'street-address': 'AVENIDA ALBUFERA 285'},
#    'location': {'latitude': 40.38752095230912,
#     'longitude': -3.639737034237325},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Miguel Hernández (línea 1).  Bus: 103, 142, 143, 54, 58, 144.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Federica Montseny'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9085-centro-especialidades-periferico-hermanos-garcia-noblejas.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9085',
#    'title': 'Centro de Especialidades Periférico Hermanos García Noblejas',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=88b57a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca/Barrio/FuenteBerro'},
#     'locality': 'MADRID',
#     'postal-code': '28028',
#     'street-address': 'CALLE DOCTOR ESQUERDO 45'},
#    'location': {'latitude': 40.423556423686065,
#     'longitude': -3.668546719643055},
#    'organization': {'organization-desc': "\xa0\xa0Metro: O'Donnell (línea 6).  Bus: C2, 143, 156, 2, 30, 56, 71, C1, E4, E5.  Bicimad: Estación 101 (calle Jorge Juan, 131).",
#     'accesibility': '2',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Hermanos García Noblejas'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9082-centro-especialidades-periferico-hermanos-sangro-pena-prieta-.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9082',
#    'title': 'Centro de Especialidades Periférico Hermanos Sangro (Peña Prieta)',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=e7267a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas/Barrio/Numancia'},
#     'locality': 'MADRID',
#     'postal-code': '28038',
#     'street-address': 'AVENIDA PEÑA PRIETA 4'},
#    'location': {'latitude': 40.398592514272686,
#     'longitude': -3.668511825547574},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Puente de Vallecas (línea 1).  Bus: 113, 141, 8, 111, 58, 37, 56, 148, 10, 136, 24, 310, 54, 57.  Bicimad: Estación 179 (avenida de la Albufera, 6).',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Hermanos Sangro (Peña Prieta)'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/40266-centro-especialidades-periferico-jose-marva.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '40266',
#    'title': 'Centro de Especialidades Periférico José Marvá',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=0d51598d1351c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan/Barrio/Valdeacederas'},
#     'locality': 'MADRID',
#     'postal-code': '28020',
#     'street-address': 'CALLE BRAVO MURILLO 317'},
#    'location': {'latitude': 40.46344389355506,
#     'longitude': -3.696754927700333},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Valdeacederas (línea 1).  Bus: 124, 66, 49.  Bicimad: Estación 207 (Azucenas, 1).',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico José Marvá'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9092-centro-especialidades-periferico-modesto-lafuente.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9092',
#    'title': 'Centro de Especialidades Periférico Modesto Lafuente',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=1bc57a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamberi'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamberi/Barrio/RiosRosas'},
#     'locality': 'MADRID',
#     'postal-code': '28003',
#     'street-address': 'CALLE MODESTO LAFUENTE 21'},
#    'location': {'latitude': 40.4400595709992,
#     'longitude': -3.6962540372344965},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Alonso Cano (línea 7).  Bus: 5.  Bicimad: Estación 129 (calle José Abascal, 33).',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Modesto Lafuente'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9081-centro-especialidades-periferico-moratalaz.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9081',
#    'title': 'Centro de Especialidades Periférico Moratalaz',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=30f57a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moratalaz'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moratalaz/Barrio/Pavones'},
#     'locality': 'MADRID',
#     'postal-code': '28030',
#     'street-address': 'CALLE HACIENDA DE PAVONES 348'},
#    'location': {'latitude': 40.39977862719607,
#     'longitude': -3.633866766863206},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Pavones (línea 9).  Bus: 20, 30, 32, 71, 8, 142, 140, 144, E4.  Bicimad: Estación 221 (calle Hacienda de Pavones, 342).',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Moratalaz'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9096-centro-especialidades-periferico-orcasitas.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9096',
#    'title': 'Centro de Especialidades Periférico Orcasitas',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=c2067a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Usera'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Usera/Barrio/Orcasitas'},
#     'locality': 'MADRID',
#     'postal-code': '28041',
#     'street-address': 'CALLE CESTONA 3'},
#    'location': {'latitude': 40.372680378354836,
#     'longitude': -3.71405352060838},
#    'organization': {'organization-desc': '\xa0\xa0Bus: 116, 121, 131, 6, 60, 78, 81.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Orcasitas'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9086-centro-especialidades-periferico-pedro-gonzalez-bueno-san-blas-.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '9086',
#    'title': 'Centro de Especialidades Periférico Pedro González Bueno (San Blas)',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=0d467a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/SanBlas-Canillejas'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/SanBlas-Canillejas/Barrio/Amposta'},
#     'locality': 'MADRID',
#     'postal-code': '28037',
#     'street-address': 'AVENIDA INSTITUCION LIBRE DE ENSE&amp;Ntilde;ANZA 89'},
#    'location': {'latitude': 40.42345514830325,
#     'longitude': -3.627133951136985},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Simancas (línea 7).  Bus: 38, 4, 48, 70, 109, 165, 167.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Centro de Especialidades Periférico Pedro González Bueno (San Blas)'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9089-centro-especialidades-periferico-pena-grande.json',
# ...
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '8924',
#    'title': 'Instituto Provincial de Oftalmología',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=f8151c7a2c61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamberi'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Chamberi/Barrio/Almagro'},
#     'locality': 'MADRID',
#     'postal-code': '28010',
#     'street-address': 'CALLE GENERAL ARRANDO 17'},
#    'location': {'latitude': 40.431826525287136,
#     'longitude': -3.693056662156631},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Rubén Darío (línea 5).  Bus: 7, 40, 147.  Bicimad: Estación 198 (glorieta Rubén Darío, 2).  Aparcamiento: Almagro (12) calle Almagro, 11.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Instituto Provincial de Oftalmología'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/8923-instituto-provincial-rehabilitacion.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '8923',
#    'title': 'Instituto Provincial de Rehabilitación',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=8b251c7a2c61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca/Barrio/Guindalera'},
#     'locality': 'MADRID',
#     'postal-code': '28028',
#     'street-address': 'CALLE FRANCISCO SILVELA 40'},
#    'location': {'latitude': 40.4330997384476,
#     'longitude': -3.6727322957984065},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Diego de León (líneas 4, 5 y 6).  Bus: 43, 48, 12, 210, 56, C2, C1, 26, 61, 1, 74.  Bicimad: Estaciones 191 (calle Alonso Heredia, 1), 192 (avenida  de los Toreros, 3).  Aparcamiento: Díaz Porlier (60) calle Diego de León, 64.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Instituto Provincial de Rehabilitación'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/25900-laboratorio-analisis-clinicos.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#    'id': '25900',
#    'title': 'Laboratorio de Análisis Clínicos',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=74ed92355c51c010VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Distrito'},
#     'locality': 'MADRID',
#     'postal-code': '28006',
#     'street-address': 'CALLE MONTESA 22 Edificio D'},
#    'location': {'latitude': 40.428976927386806,
#     'longitude': -3.6721607026353884},
#    'organization': {'organization-desc': '\xa0\xa0Metro: L2 y L6 (Manuel Becerra), L4 (Lista)Bus: 1 , 2 , 12 , 21 , 43 , 48 , 53 , 56 , 74 , 146 , 210 , Línea C Bicicletas:  Servicio Bicimad, para consultar la estación más cercana, acceda al mapa de geolocalización de las estaciones.',
#     'accesibility': '1',
#     'schedule': 'Secretaría: de lunes a viernes de 8 a 14 horas Extracciones sanguineas: de lunes a viernes de 8:30 a 10:30 horas sin cita previa',
#     'services': '',
#     'organization-name': 'Laboratorio de Análisis Clínicos'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/10168171-md-anderson-cancer-center-madrid.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/HospitalesClinicasSanatorios',
#    'id': '10168171',
#    'title': 'MD Anderson Cancer Center Madrid',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=b34c7f53ae1e7510VgnVCM2000001f4a900aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/CiudadLineal'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/CiudadLineal/Barrio/Costillares'},
#     'locality': 'MADRID',
#     'postal-code': '28033',
#     'street-address': 'CALLE ARTURO SORIA 270'},
#    'location': {'latitude': 40.47015306729349,
#     'longitude': -3.666649221736814},
#    'organization': {'organization-desc': '\xa0\xa0Bus: 107, 29, 7.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'MD Anderson Cancer Center Madrid'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9175-organizacion-nacional-trasplantes.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/OtrosCentrosMedicos',
#    'id': '9175',
#    'title': 'Organización Nacional de Trasplantes',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=d2071c7a2c61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan/Barrio/Almenara'},
#     'locality': 'MADRID',
#     'postal-code': '28029',
#     'street-address': 'CALLE SINESIO DELGADO 6 y 8 PABELLÓN 3'},
#    'location': {'latitude': 40.47406445678991,
#     'longitude': -3.687898995406082},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Begoña (línea 10),  Chamartín (línea 1, 10)  Bus: 147  Renfe: Chamartin',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Organización Nacional de Trasplantes'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9147-sanatorio-esquerdo.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/HospitalesClinicasSanatorios',
#    'id': '9147',
#    'title': 'Sanatorio Esquerdo',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=7cb9224e0d61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Latina/Barrio/LasAguilas'},
#     'locality': 'MADRID',
#     'postal-code': '28044',
#     'street-address': 'AVENIDA POBLADOS 70'},
#    'location': {'latitude': 40.38190580588028,
#     'longitude': -3.7579168409144588},
#    'organization': {'organization-desc': '\xa0\xa0Metro : Aluche (línea 5).  Bus: 121, 131, 139.   Cercanías Renfe: Aluche (línea C5).',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Sanatorio Esquerdo'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/8835-servicio-inmunoprofilaxis-rabia-humana.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosPrevencionEnfermedades',
#    'id': '8835',
#    'title': 'Servicio de Inmunoprofilaxis de la Rabia Humana',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=706f34c0e2c5f010VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca/Barrio/Lista'},
#     'locality': 'MADRID',
#     'postal-code': '28006',
#     'street-address': 'CALLE MONTESA 22'},
#    'location': {'latitude': 40.428976927386806,
#     'longitude': -3.6721607026353884},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Manuel BecerraBus: 1 , 2 , 12 , 21 , 43 , 48 , 53 , 56 , 74 , 146 , 210 , C',
#     'accesibility': '1',
#     'schedule': 'De lunes a viernes de 9 a 14 horas',
#     'services': 'Vacunaciones antirrábicas',
#     'organization-name': 'Servicio de Inmunoprofilaxis de la Rabia Humana'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/7318822-unidad-salud-mental-ninos-adolescentes-fuencarral.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosSaludMental',
#    'id': '7318822',
#    'title': 'Unidad de Salud Mental de niños y adolescentes Fuencarral',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=2cef244e96704410VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Fuencarral-ElPardo'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Fuencarral-ElPardo/Barrio/PenaGrande'},
#     'locality': 'MADRID',
#     'postal-code': '28035',
#     'street-address': 'CALLE CANDIDO MATEOS 11'},
#    'location': {'latitude': 40.47277245807722, 'longitude': -3.71813267268184},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Antonio Machado (línea 7)  Bus: 42, 127, 132',
#     'accesibility': '3',
#     'schedule': 'Consultar telefónicamente.',
#     'services': 'Atención especializada ambulatoria de salud mental.',
#     'organization-name': 'Unidad de Salud Mental de niños y adolescentes Fuencarral'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/7318897-unidad-salud-mental-ninos-adolescentes-tetuan.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosSaludMental',
#    'id': '7318897',
#    'title': 'Unidad de Salud Mental de niños y adolescentes Tetuán',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=6246244e96704410VgnVCM2000000c205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Tetuan/Barrio/Almenara'},
#     'locality': 'MADRID',
#     'postal-code': '28029',
#     'street-address': 'CALLE AGUILEÑAS 1'},
#    'location': {'latitude': 40.46548064796593,
#     'longitude': -3.6936383781020643},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Valdeacederas (línea 1), Plaza de Castilla (línea 1, 9, 10).  Bus: 124, 49, 66',
#     'accesibility': '3',
#     'schedule': 'Consultal telefónicamente.',
#     'services': 'Atención especializada ambulatoria de salud mental.',
#     'organization-name': 'Unidad de Salud Mental de niños y adolescentes Tetuán'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/4795428-unidad-movil-madrono.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#    'id': '4795428',
#    'title': 'Unidad móvil Madroño',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=d360361d139f7110VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Moncloa-Aravaca/Barrio/Arguelles'},
#     'locality': 'MADRID',
#     'postal-code': '28008',
#     'street-address': 'PASEO REY 36 Junto al albergue de San Isidro'},
#    'location': {'latitude': 40.42054836583698,
#     'longitude': -3.7179660205926224},
#    'organization': {'organization-desc': '\xa0\xa0',
#     'accesibility': '0',
#     'schedule': 'De lunes a viernes de 11:30 a 14 horas Sábado, domingo y festivo de 12:30 a 14 horas',
#     'services': '&amp;ldquo;Madroño&amp;rdquo; es un dispositivo móvil  para personas drogodependientes que no quieren o no pueden acudir a la red de centros asistenciales. Realiza intervención sociosanitaria tanto en el propio vehículo como en calle.  Programas y actividades que desarrolla   Tratamientos con metadona Intervención sanitaria: Cuidados sanitarios básicos. Vacunaciones. Educación sanitaria. Intercambio personalizado de jeringuillas. Distribución de preservativos y papel de aluminio. Estrategias de reducción del consumo y consumo de menos riesgo. Intervención social: Información y asesoramiento sobre recursos sociales. Atención psiquiátrica en proximidad. Prestaciones básicas de alimentación y vestuario. Prospecciones periódicas en el municipio de Madrid',
#     'organization-name': 'Unidad móvil Madroño'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/8889-unidad-tecnica-apoyo-diagnostico.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/CentrosPrevencionEnfermedades',
#    'id': '8889',
#    'title': 'Unidad Técnica de Apoyo Diagnóstico',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=5a057a7e0a61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/Salamanca/Barrio/Lista'},
#     'locality': 'MADRID',
#     'postal-code': '28006',
#     'street-address': 'CALLE MONTESA 22'},
#    'location': {'latitude': 40.428976927386806,
#     'longitude': -3.6721607026353884},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Manuel Becerra Bus: 1 , 2 , 12 , 21 , 43 , 48 , 53 , 56 , 74 , 146 , 210 , C',
#     'accesibility': '1',
#     'schedule': 'Antes de acudir, póngase en contacto telefónico con el centro    Horario de invierno    Citas: de lunes a viernes de 8:30 a 14:30 horas  Consulta de ITS, programa prevención del Sida: horario de admisión de pacientes CON cita previa de lunes a viernes de 8 a 9,30 horas en el teléfono 915885142   Horario de verano    Del 15 de junio al 15 de septiembre: de 8:00 a 14 horas',
#     'services': 'Centro de Diagnóstico Médico, dispone de consultas especializadas para apoyo de la Salud laboral y Prevención y control de la Tuberculosis en población sin hogar y algunas actividades de los CMSc.',
#     'organization-name': 'Unidad Técnica de Apoyo Diagnóstico'}},
#   {'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/9154-vithas-madrid-arturo-soria.json',
#    '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/CentrosAtencionMedica/HospitalesClinicasSanatorios',
#    'id': '9154',
#    'title': 'Vithas Madrid Arturo Soria',
#    'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=afe04b6faa61c010VgnVCM1000000b205a0aRCRD',
#    'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/CiudadLineal'},
#     'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/CiudadLineal/Barrio/SanJuanBautista'},
#     'locality': 'MADRID',
#     'postal-code': '28043',
#     'street-address': 'CALLE ARTURO SORIA 107'},
#    'location': {'latitude': 40.45050723288199,
#     'longitude': -3.6522677484992117},
#    'organization': {'organization-desc': '\xa0\xa0Metro: Arturo Soria (línea 4).  Bus: 11, 122, 70, 114.',
#     'accesibility': '3',
#     'schedule': '',
#     'services': '',
#     'organization-name': 'Vithas Madrid Arturo Soria'}}]}

# %%
centros = pd.json_normalize(centros['@graph'])

# %%
centros
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                 ...
# 266  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 267  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 268  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 269  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 270  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                  @type       id  \
# 0    https://datos.madrid.es/egob/kos/entidadesYorg...   134929
# 1    https://datos.madrid.es/egob/kos/entidadesYorg...    53123
# 2    https://datos.madrid.es/egob/kos/entidadesYorg...    11867
# 3    https://datos.madrid.es/egob/kos/entidadesYorg...    11887
# 4    https://datos.madrid.es/egob/kos/entidadesYorg...    11862
# ..                                                 ...      ...
# 266  https://datos.madrid.es/egob/kos/entidadesYorg...  7318822
# 267  https://datos.madrid.es/egob/kos/entidadesYorg...  7318897
# 268  https://datos.madrid.es/egob/kos/entidadesYorg...  4795428
# 269  https://datos.madrid.es/egob/kos/entidadesYorg...     8889
# 270  https://datos.madrid.es/egob/kos/entidadesYorg...     9154
#
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                                               relation  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 266  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 267  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 268  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 269  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 270  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                   address.district.@id  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...
# ..                                                 ...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 270  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                       address.area.@id address.locality  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# ..                                                 ...              ...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 270  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#     address.postal-code                        address.street-address  \
# 0                 28002                       CALLE SANTA HORTENSIA 1
# 1                 28011                              AVENIDA PORTUGAL
# 2                 28045                              PASEO CHOPERA 12
# 3                 28043                                CALLE MINAYA 7
# 4                 28047                             CALLE CAMARENA 10
# ..                  ...                                           ...
# 266               28035                       CALLE CANDIDO MATEOS 11
# 267               28029                             CALLE AGUILEÑAS 1
# 268               28008  PASEO REY 36 Junto al albergue de San Isidro
# 269               28006                              CALLE MONTESA 22
# 270               28043                        CALLE ARTURO SORIA 107
#
#      location.latitude  location.longitude  \
# 0            40.446053           -3.670277
# 1            40.416331           -3.723991
# 2            40.393057           -3.698067
# 3            40.468289           -3.636150
# 4            40.395971           -3.756272
# ..                 ...                 ...
# 266          40.472772           -3.718133
# 267          40.465481           -3.693638
# 268          40.420548           -3.717966
# 269          40.428977           -3.672161
# 270          40.450507           -3.652268
#
#                         organization.organization-desc  \
# 0    El CCAD Cáritas que forma parte de la red del ...
# 1    El CCAD  Casa de Campo que forma parte de la r...
# 2     Forma de acceso: directo, a través de los ser...
# 3     Acceso: directo, a través de los servicios mu...
# 4     Acceso: directo, a traves de los servicios mu...
# ..                                                 ...
# 266    Metro: Antonio Machado (línea 7)  Bus: 42, 1...
# 267    Metro: Valdeacederas (línea 1), Plaza de Cas...
# 268
# 269    Metro: Manuel Becerra Bus: 1 , 2 , 12 , 21 ,...
# 270    Metro: Arturo Soria (línea 4).  Bus: 11, 122...
#
#     organization.accesibility  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 266                         3
# 267                         3
# 268                         0
# 269                         1
# 270                         3
#
#                                  organization.schedule  \
# 0    De lunes a viernes mañanas de 9 a 14 horas, ta...
# 1                   De lunes a viernes de 9 a 17 horas
# 2    Horario ordinario:  De lunes a jueves de 8:30 ...
# 3    Horario ordinario:  De lunes a jueves de 8:30 ...
# 4    Horario ordinario:  De lunes a jueves de 8:30 ...
# ..                                                 ...
# 266                         Consultar telefónicamente.
# 267                         Consultal telefónicamente.
# 268  De lunes a viernes de 11:30 a 14 horas Sábado,...
# 269  Antes de acudir, póngase en contacto telefónic...
# 270
#
#                                  organization.services  \
# 0    Valoración interdisciplinar del/de la paciente...
# 1    Valoración interdisciplinar del paciente. Trat...
# 2    Valoración por equipo interdisciplinar Tratami...
# 3    Valoración por equipo interdisciplinar Tratami...
# 4    Valoración por equipo interdisciplinar Tratami...
# ..                                                 ...
# 266  Atención especializada ambulatoria de salud me...
# 267  Atención especializada ambulatoria de salud me...
# 268  &amp;ldquo;Madroño&amp;rdquo; es un dispositiv...
# 269  Centro de Diagnóstico Médico, dispone de consu...
# 270
#
#                         organization.organization-name
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
# [271 rows x 17 columns]

# %%
centros["TIPO DE LUGAR"] = "Sedes.Centros de atención médica"

# %%
centros = centros.rename(index=str, columns={"location.latitude": "lat_start", "location.longitude": "long_start"})

# %%
centros
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                 ...
# 266  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 267  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 268  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 269  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 270  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                  @type       id  \
# 0    https://datos.madrid.es/egob/kos/entidadesYorg...   134929
# 1    https://datos.madrid.es/egob/kos/entidadesYorg...    53123
# 2    https://datos.madrid.es/egob/kos/entidadesYorg...    11867
# 3    https://datos.madrid.es/egob/kos/entidadesYorg...    11887
# 4    https://datos.madrid.es/egob/kos/entidadesYorg...    11862
# ..                                                 ...      ...
# 266  https://datos.madrid.es/egob/kos/entidadesYorg...  7318822
# 267  https://datos.madrid.es/egob/kos/entidadesYorg...  7318897
# 268  https://datos.madrid.es/egob/kos/entidadesYorg...  4795428
# 269  https://datos.madrid.es/egob/kos/entidadesYorg...     8889
# 270  https://datos.madrid.es/egob/kos/entidadesYorg...     9154
#
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                                               relation  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 266  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 267  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 268  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 269  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 270  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                   address.district.@id  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...
# ..                                                 ...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 270  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                       address.area.@id address.locality  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# ..                                                 ...              ...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 270  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#     address.postal-code                        address.street-address  \
# 0                 28002                       CALLE SANTA HORTENSIA 1
# 1                 28011                              AVENIDA PORTUGAL
# 2                 28045                              PASEO CHOPERA 12
# 3                 28043                                CALLE MINAYA 7
# 4                 28047                             CALLE CAMARENA 10
# ..                  ...                                           ...
# 266               28035                       CALLE CANDIDO MATEOS 11
# 267               28029                             CALLE AGUILEÑAS 1
# 268               28008  PASEO REY 36 Junto al albergue de San Isidro
# 269               28006                              CALLE MONTESA 22
# 270               28043                        CALLE ARTURO SORIA 107
#
#      lat_start  long_start                     organization.organization-desc  \
# 0    40.446053   -3.670277  El CCAD Cáritas que forma parte de la red del ...
# 1    40.416331   -3.723991  El CCAD  Casa de Campo que forma parte de la r...
# 2    40.393057   -3.698067   Forma de acceso: directo, a través de los ser...
# 3    40.468289   -3.636150   Acceso: directo, a través de los servicios mu...
# 4    40.395971   -3.756272   Acceso: directo, a traves de los servicios mu...
# ..         ...         ...                                                ...
# 266  40.472772   -3.718133    Metro: Antonio Machado (línea 7)  Bus: 42, 1...
# 267  40.465481   -3.693638    Metro: Valdeacederas (línea 1), Plaza de Cas...
# 268  40.420548   -3.717966
# 269  40.428977   -3.672161    Metro: Manuel Becerra Bus: 1 , 2 , 12 , 21 ,...
# 270  40.450507   -3.652268    Metro: Arturo Soria (línea 4).  Bus: 11, 122...
#
#     organization.accesibility  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 266                         3
# 267                         3
# 268                         0
# 269                         1
# 270                         3
#
#                                  organization.schedule  \
# 0    De lunes a viernes mañanas de 9 a 14 horas, ta...
# 1                   De lunes a viernes de 9 a 17 horas
# 2    Horario ordinario:  De lunes a jueves de 8:30 ...
# 3    Horario ordinario:  De lunes a jueves de 8:30 ...
# 4    Horario ordinario:  De lunes a jueves de 8:30 ...
# ..                                                 ...
# 266                         Consultar telefónicamente.
# 267                         Consultal telefónicamente.
# 268  De lunes a viernes de 11:30 a 14 horas Sábado,...
# 269  Antes de acudir, póngase en contacto telefónic...
# 270
#
#                                  organization.services  \
# 0    Valoración interdisciplinar del/de la paciente...
# 1    Valoración interdisciplinar del paciente. Trat...
# 2    Valoración por equipo interdisciplinar Tratami...
# 3    Valoración por equipo interdisciplinar Tratami...
# 4    Valoración por equipo interdisciplinar Tratami...
# ..                                                 ...
# 266  Atención especializada ambulatoria de salud me...
# 267  Atención especializada ambulatoria de salud me...
# 268  &amp;ldquo;Madroño&amp;rdquo; es un dispositiv...
# 269  Centro de Diagnóstico Médico, dispone de consu...
# 270
#
#                         organization.organization-name  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                         TIPO DE LUGAR
# 0    Sedes.Centros de atención médica
# 1    Sedes.Centros de atención médica
# 2    Sedes.Centros de atención médica
# 3    Sedes.Centros de atención médica
# 4    Sedes.Centros de atención médica
# ..                                ...
# 266  Sedes.Centros de atención médica
# 267  Sedes.Centros de atención médica
# 268  Sedes.Centros de atención médica
# 269  Sedes.Centros de atención médica
# 270  Sedes.Centros de atención médica
#
# [271 rows x 18 columns]

# %%
centros1=pd.DataFrame(centros[["title", "TIPO DE LUGAR", "address.street-address", "lat_start", "long_start"]])
centros1
# Out:
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                         TIPO DE LUGAR  \
# 0    Sedes.Centros de atención médica
# 1    Sedes.Centros de atención médica
# 2    Sedes.Centros de atención médica
# 3    Sedes.Centros de atención médica
# 4    Sedes.Centros de atención médica
# ..                                ...
# 266  Sedes.Centros de atención médica
# 267  Sedes.Centros de atención médica
# 268  Sedes.Centros de atención médica
# 269  Sedes.Centros de atención médica
# 270  Sedes.Centros de atención médica
#
#                            address.street-address  lat_start  long_start
# 0                         CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1                                AVENIDA PORTUGAL  40.416331   -3.723991
# 2                                PASEO CHOPERA 12  40.393057   -3.698067
# 3                                  CALLE MINAYA 7  40.468289   -3.636150
# 4                               CALLE CAMARENA 10  40.395971   -3.756272
# ..                                            ...        ...         ...
# 266                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 267                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 268  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 269                              CALLE MONTESA 22  40.428977   -3.672161
# 270                        CALLE ARTURO SORIA 107  40.450507   -3.652268
#
# [271 rows x 5 columns]

# %%
centros2 = centros1.to_json("../../Data/centros.json")

# %%
centros1["DISTANCIA"] = centros1.apply(lambda x: to_mercator(x["lat_start"],x["long_start"]), axis = 1)

# %%
centros1
# Out:
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                Unidad Técnica de Apoyo Diagnóstico
# 270                         Vithas Madrid Arturo Soria
#
#                         TIPO DE LUGAR  \
# 0    Sedes.Centros de atención médica
# 1    Sedes.Centros de atención médica
# 2    Sedes.Centros de atención médica
# 3    Sedes.Centros de atención médica
# 4    Sedes.Centros de atención médica
# ..                                ...
# 266  Sedes.Centros de atención médica
# 267  Sedes.Centros de atención médica
# 268  Sedes.Centros de atención médica
# 269  Sedes.Centros de atención médica
# 270  Sedes.Centros de atención médica
#
#                            address.street-address  lat_start  long_start  \
# 0                         CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1                                AVENIDA PORTUGAL  40.416331   -3.723991
# 2                                PASEO CHOPERA 12  40.393057   -3.698067
# 3                                  CALLE MINAYA 7  40.468289   -3.636150
# 4                               CALLE CAMARENA 10  40.395971   -3.756272
# ..                                            ...        ...         ...
# 266                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 267                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 268  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 269                              CALLE MONTESA 22  40.428977   -3.672161
# 270                        CALLE ARTURO SORIA 107  40.450507   -3.652268
#
#                                         DISTANCIA
# 0     POINT (4502434.059450037 -408853.039316286)
# 1    POINT (4499125.341997571 -414845.0154271424)
# 2    POINT (4496534.587811412 -411953.0955810382)
# 3    POINT (4504909.304263179 -405046.3556264654)
# 4    POINT (4496858.891059969 -418446.1072378565)
# ..                                            ...
# 266  POINT (4505408.421025183 -414191.4441839741)
# 267  POINT (4504596.700436634 -411459.0382589311)
# 268  POINT (4499594.861669859 -414172.8534291824)
# 269  POINT (4500533.124849705 -409063.2065584992)
# 270  POINT (4502929.867494053 -406844.2017245693)
#
# [271 rows x 6 columns]

# %%
df_bicis = pd.merge(bicimad1, centros1, how ='cross')

# %%
df_bicis
# Out:
#                    name              address  lat_finish  long_finish  \
# 0      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# ...                 ...                  ...         ...          ...
# 71539           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71540           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71541           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71542           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71543           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
#
#                                         DISTANCIA_x  \
# 0      POINT (4499223.648366921 -412373.2851572837)
# 1      POINT (4499223.648366921 -412373.2851572837)
# 2      POINT (4499223.648366921 -412373.2851572837)
# 3      POINT (4499223.648366921 -412373.2851572837)
# 4      POINT (4499223.648366921 -412373.2851572837)
# ...                                             ...
# 71539  POINT (4501578.756909991 -411366.6317244973)
# 71540  POINT (4501578.756909991 -411366.6317244973)
# 71541  POINT (4501578.756909991 -411366.6317244973)
# 71542  POINT (4501578.756909991 -411366.6317244973)
# 71543  POINT (4501578.756909991 -411366.6317244973)
#
#                                                    title  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           TIPO DE LUGAR  \
# 0      Sedes.Centros de atención médica
# 1      Sedes.Centros de atención médica
# 2      Sedes.Centros de atención médica
# 3      Sedes.Centros de atención médica
# 4      Sedes.Centros de atención médica
# ...                                 ...
# 71539  Sedes.Centros de atención médica
# 71540  Sedes.Centros de atención médica
# 71541  Sedes.Centros de atención médica
# 71542  Sedes.Centros de atención médica
# 71543  Sedes.Centros de atención médica
#
#                              address.street-address  lat_start  long_start  \
# 0                           CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1                                  AVENIDA PORTUGAL  40.416331   -3.723991
# 2                                  PASEO CHOPERA 12  40.393057   -3.698067
# 3                                    CALLE MINAYA 7  40.468289   -3.636150
# 4                                 CALLE CAMARENA 10  40.395971   -3.756272
# ...                                             ...        ...         ...
# 71539                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 71540                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 71541  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 71542                              CALLE MONTESA 22  40.428977   -3.672161
# 71543                        CALLE ARTURO SORIA 107  40.450507   -3.652268
#
#                                         DISTANCIA_y
# 0       POINT (4502434.059450037 -408853.039316286)
# 1      POINT (4499125.341997571 -414845.0154271424)
# 2      POINT (4496534.587811412 -411953.0955810382)
# 3      POINT (4504909.304263179 -405046.3556264654)
# 4      POINT (4496858.891059969 -418446.1072378565)
# ...                                             ...
# 71539  POINT (4505408.421025183 -414191.4441839741)
# 71540  POINT (4504596.700436634 -411459.0382589311)
# 71541  POINT (4499594.861669859 -414172.8534291824)
# 71542  POINT (4500533.124849705 -409063.2065584992)
# 71543  POINT (4502929.867494053 -406844.2017245693)
#
# [71544 rows x 11 columns]

# %%
def distance_meters(DISTANCIA_x, DISTANCIA_y):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    return DISTANCIA_x.distance(DISTANCIA_y)

# %%
df_bicis["DISTANCIA"] = df_bicis.apply(lambda x: distance_meters(x["DISTANCIA_x"],x["DISTANCIA_y"]), axis = 1)

# %%
df_bicis
# Out:
#                    name              address  lat_finish  long_finish  \
# 0      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 1      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 2      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 3      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# 4      Puerta del Sol A  Puerta del Sol nº 1   40.417214    -3.701834
# ...                 ...                  ...         ...          ...
# 71539           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71540           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71541           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71542           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
# 71543           Zurbano  Calle Zurbano nº 90   40.438370    -3.692810
#
#                                         DISTANCIA_x  \
# 0      POINT (4499223.648366921 -412373.2851572837)
# 1      POINT (4499223.648366921 -412373.2851572837)
# 2      POINT (4499223.648366921 -412373.2851572837)
# 3      POINT (4499223.648366921 -412373.2851572837)
# 4      POINT (4499223.648366921 -412373.2851572837)
# ...                                             ...
# 71539  POINT (4501578.756909991 -411366.6317244973)
# 71540  POINT (4501578.756909991 -411366.6317244973)
# 71541  POINT (4501578.756909991 -411366.6317244973)
# 71542  POINT (4501578.756909991 -411366.6317244973)
# 71543  POINT (4501578.756909991 -411366.6317244973)
#
#                                                    title  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           TIPO DE LUGAR  \
# 0      Sedes.Centros de atención médica
# 1      Sedes.Centros de atención médica
# 2      Sedes.Centros de atención médica
# 3      Sedes.Centros de atención médica
# 4      Sedes.Centros de atención médica
# ...                                 ...
# 71539  Sedes.Centros de atención médica
# 71540  Sedes.Centros de atención médica
# 71541  Sedes.Centros de atención médica
# 71542  Sedes.Centros de atención médica
# 71543  Sedes.Centros de atención médica
#
#                              address.street-address  lat_start  long_start  \
# 0                           CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1                                  AVENIDA PORTUGAL  40.416331   -3.723991
# 2                                  PASEO CHOPERA 12  40.393057   -3.698067
# 3                                    CALLE MINAYA 7  40.468289   -3.636150
# 4                                 CALLE CAMARENA 10  40.395971   -3.756272
# ...                                             ...        ...         ...
# 71539                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 71540                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 71541  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 71542                              CALLE MONTESA 22  40.428977   -3.672161
# 71543                        CALLE ARTURO SORIA 107  40.450507   -3.652268
#
#                                         DISTANCIA_y    DISTANCIA
# 0       POINT (4502434.059450037 -408853.039316286)  4764.333123
# 1      POINT (4499125.341997571 -414845.0154271424)  2473.684432
# 2      POINT (4496534.587811412 -411953.0955810382)  2721.691744
# 3      POINT (4504909.304263179 -405046.3556264654)  9274.188877
# 4      POINT (4496858.891059969 -418446.1072378565)  6516.996635
# ...                                             ...          ...
# 71539  POINT (4505408.421025183 -414191.4441839741)  4758.770079
# 71540  POINT (4504596.700436634 -411459.0382589311)  3019.357895
# 71541  POINT (4499594.861669859 -414172.8534291824)  3436.672894
# 71542  POINT (4500533.124849705 -409063.2065584992)  2529.646991
# 71543  POINT (4502929.867494053 -406844.2017245693)  4719.944164
#
# [71544 rows x 12 columns]

# %%
df_final = pd.DataFrame(df_bicis[["title", "TIPO DE LUGAR", "address.street-address", "DISTANCIA", "name", "address"]])
df_final
# Out:
#                                                    title  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           TIPO DE LUGAR  \
# 0      Sedes.Centros de atención médica
# 1      Sedes.Centros de atención médica
# 2      Sedes.Centros de atención médica
# 3      Sedes.Centros de atención médica
# 4      Sedes.Centros de atención médica
# ...                                 ...
# 71539  Sedes.Centros de atención médica
# 71540  Sedes.Centros de atención médica
# 71541  Sedes.Centros de atención médica
# 71542  Sedes.Centros de atención médica
# 71543  Sedes.Centros de atención médica
#
#                              address.street-address    DISTANCIA  \
# 0                           CALLE SANTA HORTENSIA 1  4764.333123
# 1                                  AVENIDA PORTUGAL  2473.684432
# 2                                  PASEO CHOPERA 12  2721.691744
# 3                                    CALLE MINAYA 7  9274.188877
# 4                                 CALLE CAMARENA 10  6516.996635
# ...                                             ...          ...
# 71539                       CALLE CANDIDO MATEOS 11  4758.770079
# 71540                             CALLE AGUILEÑAS 1  3019.357895
# 71541  PASEO REY 36 Junto al albergue de San Isidro  3436.672894
# 71542                              CALLE MONTESA 22  2529.646991
# 71543                        CALLE ARTURO SORIA 107  4719.944164
#
#                    name              address
# 0      Puerta del Sol A  Puerta del Sol nº 1
# 1      Puerta del Sol A  Puerta del Sol nº 1
# 2      Puerta del Sol A  Puerta del Sol nº 1
# 3      Puerta del Sol A  Puerta del Sol nº 1
# 4      Puerta del Sol A  Puerta del Sol nº 1
# ...                 ...                  ...
# 71539           Zurbano  Calle Zurbano nº 90
# 71540           Zurbano  Calle Zurbano nº 90
# 71541           Zurbano  Calle Zurbano nº 90
# 71542           Zurbano  Calle Zurbano nº 90
# 71543           Zurbano  Calle Zurbano nº 90
#
# [71544 rows x 6 columns]

# %%
df_final = df_final.rename(index=str, columns={"title": "Place of Interest", "TIPO DE LUGAR": "Type of Place", "address.street-address": "Place Address", "name": "BiciMad Station", "address": "Station location"})

# %%
df_final
# Out:
#                                        Place of Interest  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro de Atención a las Adicciones (CAD) de A...
# 3      Centro de Atención a las Adicciones (CAD) de H...
# 4      Centro de Atención a las Adicciones (CAD) de L...
# ...                                                  ...
# 71539  Unidad de Salud Mental de niños y adolescentes...
# 71540  Unidad de Salud Mental de niños y adolescentes...
# 71541                               Unidad móvil Madroño
# 71542                Unidad Técnica de Apoyo Diagnóstico
# 71543                         Vithas Madrid Arturo Soria
#
#                           Type of Place  \
# 0      Sedes.Centros de atención médica
# 1      Sedes.Centros de atención médica
# 2      Sedes.Centros de atención médica
# 3      Sedes.Centros de atención médica
# 4      Sedes.Centros de atención médica
# ...                                 ...
# 71539  Sedes.Centros de atención médica
# 71540  Sedes.Centros de atención médica
# 71541  Sedes.Centros de atención médica
# 71542  Sedes.Centros de atención médica
# 71543  Sedes.Centros de atención médica
#
#                                       Place Address    DISTANCIA  \
# 0                           CALLE SANTA HORTENSIA 1  4764.333123
# 1                                  AVENIDA PORTUGAL  2473.684432
# 2                                  PASEO CHOPERA 12  2721.691744
# 3                                    CALLE MINAYA 7  9274.188877
# 4                                 CALLE CAMARENA 10  6516.996635
# ...                                             ...          ...
# 71539                       CALLE CANDIDO MATEOS 11  4758.770079
# 71540                             CALLE AGUILEÑAS 1  3019.357895
# 71541  PASEO REY 36 Junto al albergue de San Isidro  3436.672894
# 71542                              CALLE MONTESA 22  2529.646991
# 71543                        CALLE ARTURO SORIA 107  4719.944164
#
#         BiciMad Station     Station location
# 0      Puerta del Sol A  Puerta del Sol nº 1
# 1      Puerta del Sol A  Puerta del Sol nº 1
# 2      Puerta del Sol A  Puerta del Sol nº 1
# 3      Puerta del Sol A  Puerta del Sol nº 1
# 4      Puerta del Sol A  Puerta del Sol nº 1
# ...                 ...                  ...
# 71539           Zurbano  Calle Zurbano nº 90
# 71540           Zurbano  Calle Zurbano nº 90
# 71541           Zurbano  Calle Zurbano nº 90
# 71542           Zurbano  Calle Zurbano nº 90
# 71543           Zurbano  Calle Zurbano nº 90
#
# [71544 rows x 6 columns]

# %%
df_final1 = df_final.to_csv("../../Data/df_final.csv")

# %%
def bicimad_station():
    i = str(input("Introduzca lugar "))
    x = df_final[df_final["Place of Interest"] == i]
    return x.sort_values(by = "DISTANCIA", ascending = True).head(1)

# %%
# %%time
bicimad_station ()
# Out:
# Introduzca lugar Unidad móvil Madroño
# CPU times: user 38.7 ms, sys: 10.5 ms, total: 49.2 ms
# Wall time: 2.08 s
#           Place of Interest                     Type of Place  \
# 34414  Unidad móvil Madroño  Sedes.Centros de atención médica
#
#                                       Place Address   DISTANCIA  \
# 34414  PASEO REY 36 Junto al albergue de San Isidro  529.669171
#
#            BiciMad Station          Station location
# 34414  Paseo de la Florida  Paseo de la Florida nº 8

# %%
final_res = bicimad_station().sort_values(by = "DISTANCIA", ascending = True).head(1)
# Out:
# Introduzca lugar Unidad móvil Madroño

# %%
final_res.to_csv("../../Data/final_res.csv")
final_res
# Out:
#           Place of Interest                     Type of Place  \
# 34414  Unidad móvil Madroño  Sedes.Centros de atención médica
#
#                                       Place Address   DISTANCIA  \
# 34414  PASEO REY 36 Junto al albergue de San Isidro  529.669171
#
#            BiciMad Station          Station location
# 34414  Paseo de la Florida  Paseo de la Florida nº 8

# %%
def bicimad():
    return df_final.sort_values(by = "DISTANCIA", ascending = True).groupby('Place of Interest')['Type of Place','Place Address', 'DISTANCIA','BiciMad Station', 'Station location'].nth(0).drop(["DISTANCIA"], axis = "columns")

# %%
bicimad()
# Out:
# /Users/pabloaliagagato/applications/envs/project1/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                        Type of Place  \
# Place of Interest
# CMSc Centro Municipal de Salud Comunitaria  Cha...  Sedes.Centros de atención médica
# CMSc Centro Municipal de Salud Comunitaria Arga...  Sedes.Centros de atención médica
# CMSc Centro Municipal de Salud Comunitaria Cara...  Sedes.Centros de atención médica
# CMSc Centro Municipal de Salud Comunitaria Centro   Sedes.Centros de atención médica
# CMSc Centro Municipal de Salud Comunitaria Ciud...  Sedes.Centros de atención médica
# ...                                                                              ...
# Unidad Técnica de Apoyo Diagnóstico                 Sedes.Centros de atención médica
# Unidad de Salud Mental de niños y adolescentes ...  Sedes.Centros de atención médica
# Unidad de Salud Mental de niños y adolescentes ...  Sedes.Centros de atención médica
# Unidad móvil Madroño                                Sedes.Centros de atención médica
# Vithas Madrid Arturo Soria                          Sedes.Centros de atención médica
#
#                                                                                    Place Address  \
# Place of Interest
# CMSc Centro Municipal de Salud Comunitaria  Cha...                          CALLE RAFAEL CALVO 6
# CMSc Centro Municipal de Salud Comunitaria Arga...         CALLE CONCEJAL BENITO MARTIN LOZANO 1
# CMSc Centro Municipal de Salud Comunitaria Cara...                   CALLE EUGENIA DE MONTIJO 90
# CMSc Centro Municipal de Salud Comunitaria Centro                       CALLE NAVAS DE TOLOSA 10
# CMSc Centro Municipal de Salud Comunitaria Ciud...                   PLAZA DE AGUSTÍN GONZALEZ 1
# ...                                                                                          ...
# Unidad Técnica de Apoyo Diagnóstico                                             CALLE MONTESA 22
# Unidad de Salud Mental de niños y adolescentes ...                       CALLE CANDIDO MATEOS 11
# Unidad de Salud Mental de niños y adolescentes ...                             CALLE AGUILEÑAS 1
# Unidad móvil Madroño                                PASEO REY 36 Junto al albergue de San Isidro
# Vithas Madrid Arturo Soria                                                CALLE ARTURO SORIA 107
#
#                                                              BiciMad Station  \
# Place of Interest
# CMSc Centro Municipal de Salud Comunitaria  Cha...  General Martínez Campos
# CMSc Centro Municipal de Salud Comunitaria Arga...          Puerta de Toledo
# CMSc Centro Municipal de Salud Comunitaria Cara...                  Caramuel
# CMSc Centro Municipal de Salud Comunitaria Centro                Jacometrezo
# CMSc Centro Municipal de Salud Comunitaria Ciud...     Marqués de Corbera 52
# ...                                                                      ...
# Unidad Técnica de Apoyo Diagnóstico                       Ortega y Gasset 87
# Unidad de Salud Mental de niños y adolescentes ...         Francos Rodríguez
# Unidad de Salud Mental de niños y adolescentes ...                   Remonta
# Unidad móvil Madroño                                     Paseo de la Florida
# Vithas Madrid Arturo Soria                                   Carlota O’Neill
#
#                                                                         Station location
# Place of Interest
# CMSc Centro Municipal de Salud Comunitaria  Cha...       Calle Fernández de la Hoz nº 29
# CMSc Centro Municipal de Salud Comunitaria Arga...  Glorieta de la Puerta de Toledo nº 1
# CMSc Centro Municipal de Salud Comunitaria Cara...                  Calle Caramuel nº 51
# CMSc Centro Municipal de Salud Comunitaria Centro                 Calle Jacometrezo nº 3
# CMSc Centro Municipal de Salud Comunitaria Ciud...      Avenida Marqués de Corbera nº 52
# ...                                                                                  ...
# Unidad Técnica de Apoyo Diagnóstico                          Calle Ortega y Gasset nº 87
# Unidad de Salud Mental de niños y adolescentes ...         Calle Francos Rodríguez nº 62
# Unidad de Salud Mental de niños y adolescentes ...                   Calle Azucenas nº 1
# Unidad móvil Madroño                                            Paseo de la Florida nº 8
# Vithas Madrid Arturo Soria                                   Calle Carlota O'Neill nº 32
#
# [271 rows x 4 columns]
